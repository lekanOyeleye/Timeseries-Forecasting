# %% [markdown]
# # Forecasting a timeseries

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import itertools
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")  # ignore convergence warnings

# %% [raw]
# !pip install tensorflow

# %%
path = Path('CTA_-_Ridership_-_Daily_Boarding_Totals_20250901.csv')
df = pd.read_csv(path, parse_dates=['service_date'])
df.columns = ["date", "day_type", "bus", "rail", "total"]  # shorter names
df = df.sort_values("date").set_index("date")
df = df.drop("total", axis=1)  # no need for total, it's just bus + rail
df = df.drop_duplicates()  # remove duplicated months 

df.dtypes
# Out:
# day_type    object
# bus         object
# rail        object
# dtype: object

# %% [markdown]
# ## Convert Bus and Rail into numeric data

# %%
df["bus"] = df["bus"].astype(str).str.replace(",", "").astype(int)
df["rail"] = df["rail"].astype(str).str.replace(",", "").astype(int)

# %%
df.head()
# Out:
#            day_type     bus    rail
# date
# 2001-01-01        U  297192  126455
# 2001-01-02        W  780827  501952
# 2001-01-03        W  824923  536432
# 2001-01-04        W  870021  550011
# 2001-01-05        W  890426  557917

# %% [markdown]
# ## W - means weekdays , A - Saturday, U - Sunday

# %%
df.tail()
# Out:
#            day_type     bus    rail
# date
# 2025-06-26        W  561301  471300
# 2025-06-27        W  543140  416639
# 2025-06-28        A  427366  337560
# 2025-06-29        U  316118  323242
# 2025-06-30        W  534839  376363

# %%
df.loc["2025-03":"2025-05"].plot(grid=True, marker='.', figsize=(8,3.5))
plt.show()

# %% [markdown]
# # Naive Forecasting
#
# ---
# The naive forecasting is adopting the current/previous day, week, month data to forecast the next day, week, or month. This can serve as a baseline forecast.
#
# From the graph below, we use the previous 7 days to forecast the next 7 days for the period of March to May 2021 and it was very close in its predictions.
#
# ---

# %%
diff_7 = df[['bus', 'rail']].diff(7)["2025-03":"2025-05"]

fig, axs = plt.subplots(2, 1, sharex=True, figsize=(8, 5))
df.plot(ax=axs[0], legend=False, marker=".")  # original time series
axs[0].set_title("Original and 7-Day Lagged Time Series")


df.shift(7).plot(ax=axs[0], grid=True, legend=False, linestyle=":")  # lagged
diff_7.plot(ax=axs[1], grid=True, marker=".")  # 7-day difference time series
axs[1].set_title("7-Day Difference Time Series")

plt.show()

# %% [markdown]
# ### Lets get the Mean Absolute Error for the period

# %%
diff_7.abs().mean()
# Out:
# bus     28896.891304
# rail    29453.489130
# dtype: float64

# %% [markdown]
# ### Get the Mean Abssolute Percentage Error (MAPE)

# %%
targets = df[['bus', 'rail']]["2025-03":"2025-05"]
(diff_7/targets).abs().mean()
# Out:
# bus     0.059459
# rail    0.086405
# dtype: float64

# %% [markdown]
# ---
# We can notice that the bus has a better MAE but worse MAPE than that of rail, however, the MAPE is very close for both bus and rail compared to the MAE.
#
# This is because bus ridership are larger hence their forecast error will also be larger. But the percentage error will put things in the proper perspective.
#
# MAPE :
# bus - 5.9% ;
# rail - 8.6%
#
# ---

# %%
def naive_next(df_slice, df_full, cols, seasonal=False, season=7):
    """
    Naive or seasonal naive forecast for the next day,
    using a pre-sliced DataFrame for the forecast, 
    and the full DataFrame for the observed value.

    Parameters
    ----------
    df_slice : pd.DataFrame
        Pre-sliced DataFrame (e.g., df.loc["2025-03":"2025-05"])
    df_full : pd.DataFrame
        The original full DataFrame containing all dates
    cols : list
        List of numeric columns to forecast (e.g., ["bus", "rail"])
    seasonal : bool, default False
        If True, use seasonal naive (t = t-season)
    season : int, default 7
        Seasonal lag (e.g., 7 for weekly)

    Returns
    -------
    dict with:
        - forecast : pd.DataFrame
        - observed : pd.Series (true next-day values from df_full)
    """
    df_slice = df_slice.sort_index()
    
    # last day in the slice and next day
    last_day = df_slice.index[-1]
    next_day = last_day + pd.Timedelta(days=1)

    # forecast
    if seasonal:
        vals = df_slice.loc[last_day - pd.Timedelta(days=season-1), cols]
    else:
        vals = df_slice.loc[last_day, cols]
    forecast = pd.DataFrame([vals.values], index=[next_day], columns=cols)

    # true observed value from full df
    observed = df_full.loc[next_day, cols] if next_day in df_full.index else None

    return {"forecast": forecast, "observed": observed}

# %%
# Slice your data
df_slice = df.loc["2025-03":"2025-05"]

# Call the function with the slice and the full DataFrame
result_naive = naive_next(df_slice, df, ["bus", "rail"])
result_seasonal = naive_next(df_slice, df, ["bus", "rail"], seasonal=True)

# Print results
print("Naive forecast:\n", result_naive["forecast"], "\n")
print("Observed:\n", result_naive["observed"], "\n")

print("Seasonal naive forecast:\n", result_seasonal["forecast"], "\n")
print("Observed:\n", result_seasonal["observed"])
# Out:
# Naive forecast:
#                 bus    rail
# 2025-06-01  421327  334489
#
# Observed:
#  bus     322578
# rail    268696
# Name: 2025-06-01 00:00:00, dtype: object
#
# Seasonal naive forecast:
#                 bus    rail
# 2025-06-01  331906  272960
#
# Observed:
#  bus     322578
# rail    268696
# Name: 2025-06-01 00:00:00, dtype: object

# %% [markdown]
# ---
# The Naive forecast using day for bus is 468550 while rail is 326376, however using the 7 days period - for bus is 461780 for rail 319883
#
# ---

# %% [markdown]
# ### Yearly Seasonality - 2001 to 2023

# %%
period = slice("2001", "2025") 

# Select only numeric columns
df_numeric = df[["bus", "rail"]]

# Resample monthly and compute mean
df_monthly = df_numeric.resample('M').mean()

# 12-month rolling average
rolling_average_12_months = df_monthly["2001":"2025"].rolling(window=12).mean()

# Plot
fig, ax = plt.subplots(figsize=(10, 5))
df_monthly["2001":"2023"].plot(ax=ax, marker=".", label="Monthly Mean")
rolling_average_12_months.plot(ax=ax, grid=True, label="12-Month Rolling Avg")
ax.set_title("Yearly Seasonality and Longterm trends (2001–2025)")
ax.set_xlabel("Date")
ax.set_ylabel("Ridership")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The 12-Months difference

# %%
df_monthly.diff(12)[period].plot(grid=True, marker=".", figsize=(8, 3))
plt.gca().set_title("The 12-Month Difference")
plt.show()

# %% [markdown]
# ---
# The difference removed the yearly seasonality forecast except for the year 2020 which is the period of COVID/Lock Down
#
# ---

# %% [markdown]
# # ARMA MODELS - autoregressive moving average model
#
# ---
# ## What ARMA stands for
#
# ARMA = AutoRegressive Moving Average.
# It’s a statistical model used to predict future values of a time series (like stock prices, temperature, or ridership) based on its past behavior.
#
# It has two parts:
#
# - AR (AutoRegressive) – uses past values of the series itself.
#
# - MA (Moving Average) – uses past “errors” or shocks (differences between actual and predicted values).
#
# ## AutoRegressive (AR) part
#
# - Think of it like this: the future value depends on some number of past values.
#
# - Example: today’s temperature might depend on yesterday’s temperature and the day before.
#
# - We call the number of past values we use p, the “order” of the AR part.
#
# $$
# X_t = c + \phi_1 X_{t-1} + \cdots + \phi_p X_{t-p} + \epsilon_t + \theta_1 \epsilon_{t-1} + \cdots + \theta_q \epsilon_{t-q} + error
# $$
#
# $$
# \begin{aligned}
# \text{Where:} \\
# X_t &= \text{value at time } t \\
# c &= \text{constant term} \\
# \phi_1, \phi_2, \dots, \phi_p &= \text{coefficients (how much past values influence the current value)} \\
# \text{error} &= \text{random noise}
# \end{aligned}
# $$
#
# ## Moving Average (MA) part
#
# This part looks at past errors instead of past values.
#
# Why? Sometimes patterns are not obvious from past values alone, but the mistakes we made in predicting before can help forecast future values.
#
# We call the number of past errors we include q, the “order” of the MA part.
#
# $$
# \begin{aligned}
# X_t &= c + \epsilon_t + \theta_1 \epsilon_{t-1} + \dots + \theta_q \epsilon_{t-q} \\[1mm]
# \text{Where:} \\
# \theta_1, \theta_2, \dots, \theta_q &= \text{coefficients for past errors} \\
# \epsilon_t &= \text{random noise at time } t
# \end{aligned}
# $$
#
# ## ARMA combines both
#
# An ARMA(p, q) model uses both: p past values (AR) q past errors (MA)
#
# $$
# \begin{aligned}
# X_t &= c + \phi_1 X_{t-1} + \phi_2 X_{t-2} + \dots + \phi_p X_{t-p} + \epsilon_t + \theta_1 \epsilon_{t-1} + \dots + \theta_q \epsilon_{t-q} \\[1mm]
# \text{Where:} \\
# X_t &= \text{value at time } t \\
# c &= \text{constant term} \\
# \phi_1, \phi_2, \dots, \phi_p &= \text{coefficients for past values (AR part)} \\
# \theta_1, \theta_2, \dots, \theta_q &= \text{coefficients for past errors (MA part)} \\
# \epsilon_t &= \text{random noise at time } t
# \end{aligned}
# $$
#
# ## Key points to remember
#
# Stationarity: ARMA works best when the data fluctuates around a constant mean and variance over time. If the series trends upwards or grows, we usually difference it first (leading to ARIMA).
#
# p and q: These are the “orders” you choose based on patterns in the data (autocorrelation and partial autocorrelation plots help).
#
# Error term: Random noise in your data that you can’t predict.
#
# ## Intuition / Example
#
# Imagine you’re forecasting daily bus ridership:
#
# AR part: “Ridership today is probably similar to yesterday and the day before.”
#
# MA part: “Yesterday we overpredicted by 500 passengers, so maybe today will be slightly lower to compensate.”
#
# Combine both, and ARMA gives a formula that weighs past ridership and past mistakes to make the best estimate for today.
#
# ## This model assumes stationarity  of the series
#
# ---

# %% [raw]
# !pip install statsmodels

# %%
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ## ARIMA
# ---
# 1. AR (Autoregressive) – “I look at the past”
#
# Idea: Today’s value depends on previous days.
#
# Example: If yesterday 100 people rode the train, today might be similar, maybe a bit more or less.
#
# Parameter p = how many previous days you consider.
#
# 2. MA (Moving Average) – “I fix past mistakes”
#
# Idea: If my past predictions were off, I adjust today’s forecast to compensate.
#
# Example: Yesterday I predicted 110 riders but only 100 came. Today I’ll adjust down a bit.
#
# Parameter q = how many past prediction mistakes I consider.
#
# 3. I (Integrated / Differencing) – “I remove trends”
#
# Idea: If the series is trending up or down, we first look at changes rather than raw numbers.
#
# Example: Instead of looking at 100 → 110 → 120, look at the differences: +10, +10.
#
# Parameter d = how many times we calculate these changes to make the series stable.
#
# 4. Seasonal part – “I look at repeating patterns”
#
# Idea: Some patterns repeat after a fixed time (like weekly or monthly).
#
# Example: Train rides go up on Mondays and down on Sundays. That’s weekly seasonality.
#
# Seasonal parameters (P, D, Q, s):
#
# P = AR for seasonal pattern (depends on same day last week)
#
# D = differencing to remove seasonal trend
#
# Q = MA for seasonal errors
#
# s = length of the season (7 for a week, 12 for months)
#
# 5. Your model in layman terms
# order=(1,0,0)
# seasonal_order=(0,1,1,7)
#
#
# Look at yesterday’s rides to predict today (AR(1))
#
# Ignore overall trend (d=0)
#
# Weekly pattern: subtract last week’s value to remove seasonality (D=1, s=7)
#
# Adjust for last week’s prediction error (Q=1)
#
# ✅ In short: “Today’s train rides = yesterday’s rides + weekly pattern + small adjustment for last week’s mistake.”
#
# ---

# %%
origin, today = "2025-01-01", "2025-05-31"
rail_series = df.loc[origin:today]["rail"].asfreq("D")
model = ARIMA(rail_series, order=(1, 0, 0), seasonal_order=(0, 1, 1, 7))
model = model.fit()
y_pred = model.forecast()

# %%
print(y_pred)
# Out:
# 2025-06-01    260176.111208
# Freq: D, dtype: float64

# %% [markdown]
# ---
# from the forecast with the ARIMA model(317978), we can see that it is worse than the Naive Forecasting(319883). The observed is 346924
#
# ---

# %% [markdown]
# # Lets check the MAE for the ARIMA model to see its performance on more days.

# %%
origin, start_date, end_date = "2025-01-01", "2025-03-01", "2025-05-31"
time_period = pd.date_range(start_date, end_date)
rail_series = df.loc[origin:end_date]["rail"].asfreq("D")
y_preds = []
for today in time_period.shift(-1):
    model = ARIMA(rail_series[origin:today],  # train on data up to "today"
                  order=(1, 0, 0),
                  seasonal_order=(0, 1, 1, 7))
    model = model.fit()  # note that we retrain the model every day!
    y_pred = model.forecast()[0]
    y_preds.append(y_pred)
y_preds = pd.Series(y_preds, index=time_period)
mae = (y_preds - rail_series[time_period]).abs().mean()  
print(mae)
# Out:
# 25162.19345016908

# %%
print(mae)
# Out:
# 25162.19345016908

# %% [markdown]
# ---
# The MAE for the ARIMA model is 20,600.8 compared to the Naive Forecasting 21245.152174. Therefore the ARIMA model is better but just slightly off for the prediction on 1st June 2025.
#
# ---

# %% [markdown]
# # GRIDSEARCH

# %% [raw]
# # Define the data and time period
# origin, start_date, end_date = "2025-01-01", "2025-03-01", "2025-05-31"
# time_period = pd.date_range(start_date, end_date)
# rail_series = df.loc[origin:end_date]["rail"].asfreq("D")
#
# # Define the ARIMA hyperparameter grid
# p = range(1, 3)  # AR terms
# d = range(0, 2)  # differencing
# q = range(0, 2)  # MA terms
# P = range(0, 1)
# D = range(0, 2)
# Q = range(0, 3)
# s = 7
#
# param_grid = list(itertools.product(p, d, q, P, D, Q))
#
# best_mae = float("inf")
# best_params = None
#
# # Loop through all parameter combinations
# for params in param_grid:
#     p_val, d_val, q_val, P_val, D_val, Q_val = params
#     seasonal_order = (P_val, D_val, Q_val, s)
#     order = (p_val, d_val, q_val)
#     y_preds_sarimax = []
#
#     for today in time_period.shift(-1):
#         model = SARIMAX(
#             rail_series[origin:today],
#             order=order,
#             seasonal_order=seasonal_order,
#             enforce_stationarity=False,
#             enforce_invertibility=False
#         )
#         model_fit = model.fit(disp=False)
#         y_pred = model_fit.forecast()[0]
#         y_preds_sarimax.append(y_pred)
#
#     y_preds_sarimax = pd.Series(y_preds_sarimax, index=time_period)
#     mae_sarimax = (y_preds_sarimax - rail_series[time_period]).abs().mean()
#
#
#     if mae_sarimax < best_mae:
#         best_mae = mae_sarimax
#         best_params = params
#         print(f"New best MAE: {mae_sarimax:.2f} with params {params + (s,)}, ")
#
# print(f"\nBest SARIMAX params: {best_params} with MAE: {best_mae:.2f}")

# %% [raw]
# origin, today = "2025-01-01", "2025-05-31"
# rail_series = df.loc[origin:today]["rail"].asfreq("D")
# model = SARIMAX(rail_series, order=(1, 1, 1), seasonal_order=(0, 1, 1, 7), enforce_stationarity=False, enforce_invertibility=False)
# model = model.fit()
# y_pred = model.forecast()
# print(y_pred)

# %% [markdown]
# ---
# At this point, the Naive forecast got a better forecast for the 1st of June 2025, however the MAE is higher than that of the ARIMA model which means in the long run the model would get alot wrong that the ARIMA model.
#
# |                          | Seasonal Naive Forecast |   ARIMA   |
# |--------------------------|--------------------------|-----------|
# | **MAE**                  | 29,453.49                | 25,162.19 |
# | **Forecast (1st June 2025)** | 268,696                  | 260,176.11 |
# | **Observed**             | 272,960                  | 272,960   |
# | **Error %**              | 1.56%                    | 4.68%     |
#
#
# ---

# %% [markdown]
# # Preparing Data For Deep Learning

# %%
rail_train = df["rail"]["2022-01":"2024-12"] / 1e6
rail_valid = df["rail"]["2025-01":"2025-05"] / 1e6
rail_test = df["rail"]["2025-06":] / 1e6

# %%
seq_length = 56

train_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_train.to_numpy(),
    targets=rail_train[seq_length:],
    sequence_length=seq_length,
    batch_size=32,
    shuffle=True,
    seed=42
)

valid_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_valid.to_numpy(),
    targets=rail_valid[seq_length:],
    sequence_length=seq_length,
    batch_size=32
)

# %% [markdown]
# ## Forecasting Using a Linear Model

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([tf.keras.layers.Dense(1, input_shape=[seq_length])])
early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor="val_mae", patience=50, restore_best_weights=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.02, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(), optimizer=opt, metrics=["mae"])
history = model.fit(train_ds, validation_data=valid_ds, epochs=500, callbacks=[early_stopping_cb])
# Out:
# Epoch 1/500
# 33/33 [==============================] - 7s 39ms/step - loss: 0.0086 - mae: 0.1032 - val_loss: 0.0087 - val_mae: 0.1060
# Epoch 2/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0051 - mae: 0.0776 - val_loss: 0.0049 - val_mae: 0.0780
# Epoch 3/500
# 33/33 [==============================] - 1s 27ms/step - loss: 0.0039 - mae: 0.0690 - val_loss: 0.0041 - val_mae: 0.0701
# Epoch 4/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0035 - mae: 0.0640 - val_loss: 0.0047 - val_mae: 0.0771
# Epoch 5/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0032 - mae: 0.0615 - val_loss: 0.0042 - val_mae: 0.0730
# Epoch 6/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0030 - mae: 0.0596 - val_loss: 0.0032 - val_mae: 0.0613
# Epoch 7/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0027 - mae: 0.0564 - val_loss: 0.0029 - val_mae: 0.0578
# Epoch 8/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0025 - mae: 0.0536 - val_loss: 0.0028 - val_mae: 0.0576
# Epoch 9/500
# 33/33 [==============================] - 1s 25ms/step - loss: 0.0023 - mae: 0.0517 - val_loss: 0.0024 - val_mae: 0.0528
# Epoch 10/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0023 - mae: 0.0523 - val_loss: 0.0024 - val_mae: 0.0525
# Epoch 11/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0021 - mae: 0.0485 - val_loss: 0.0025 - val_mae: 0.0542
# Epoch 12/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0020 - mae: 0.0474 - val_loss: 0.0024 - val_mae: 0.0532
# Epoch 13/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0020 - mae: 0.0474 - val_loss: 0.0022 - val_mae: 0.0499
# Epoch 14/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0018 - mae: 0.0452 - val_loss: 0.0021 - val_mae: 0.0494
# Epoch 15/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0018 - mae: 0.0444 - val_loss: 0.0020 - val_mae: 0.0479
# Epoch 16/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0017 - mae: 0.0440 - val_loss: 0.0020 - val_mae: 0.0473
# Epoch 17/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0017 - mae: 0.0429 - val_loss: 0.0022 - val_mae: 0.0507
# Epoch 18/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0017 - mae: 0.0427 - val_loss: 0.0023 - val_mae: 0.0526
# Epoch 19/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0016 - mae: 0.0416 - val_loss: 0.0018 - val_mae: 0.0445
# Epoch 20/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0015 - mae: 0.0406 - val_loss: 0.0019 - val_mae: 0.0462
# Epoch 21/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0015 - mae: 0.0411 - val_loss: 0.0018 - val_mae: 0.0450
# Epoch 22/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0015 - mae: 0.0404 - val_loss: 0.0019 - val_mae: 0.0469
# Epoch 23/500
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0015 - mae: 0.0401 - val_loss: 0.0020 - val_mae: 0.0487
# Epoch 24/500
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0014 - mae: 0.0392 - val_loss: 0.0017 - val_mae: 0.0430
# Epoch 25/500
# 33/33 [==============================] - 1s 27ms/step - loss: 0.0014 - mae: 0.0395 - val_loss: 0.0017 - val_mae: 0.0437
# Epoch 26/500
# 33/33 [==============================] - 1s 25ms/step - loss: 0.0014 - mae: 0.0385 - val_loss: 0.0016 - val_mae: 0.0415
# Epoch 27/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0013 - mae: 0.0379 - val_loss: 0.0016 - val_mae: 0.0407
# Epoch 28/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0013 - mae: 0.0383 - val_loss: 0.0016 - val_mae: 0.0409
# Epoch 29/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0013 - mae: 0.0377 - val_loss: 0.0015 - val_mae: 0.0401
# Epoch 30/500
# 33/33 [==============================] - 1s 25ms/step - loss: 0.0013 - mae: 0.0374 - val_loss: 0.0016 - val_mae: 0.0412
# Epoch 31/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0013 - mae: 0.0373 - val_loss: 0.0017 - val_mae: 0.0435
# Epoch 32/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0013 - mae: 0.0373 - val_loss: 0.0016 - val_mae: 0.0410
# Epoch 33/500
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0012 - mae: 0.0365 - val_loss: 0.0015 - val_mae: 0.0396
# Epoch 34/500
# 33/33 [==============================] - 1s 25ms/step - loss: 0.0012 - mae: 0.0364 - val_loss: 0.0015 - val_mae: 0.0391
# Epoch 35/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0012 - mae: 0.0359 - val_loss: 0.0017 - val_mae: 0.0436
# Epoch 36/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0012 - mae: 0.0355 - val_loss: 0.0015 - val_mae: 0.0397
# Epoch 37/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0012 - mae: 0.0355 - val_loss: 0.0015 - val_mae: 0.0389
# Epoch 38/500
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0012 - mae: 0.0355 - val_loss: 0.0014 - val_mae: 0.0376
# Epoch 39/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0012 - mae: 0.0355 - val_loss: 0.0014 - val_mae: 0.0376
# Epoch 40/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0011 - mae: 0.0349 - val_loss: 0.0014 - val_mae: 0.0375
# Epoch 41/500
# 33/33 [==============================] - 1s 25ms/step - loss: 0.0011 - mae: 0.0348 - val_loss: 0.0014 - val_mae: 0.0379
# Epoch 42/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0012 - mae: 0.0354 - val_loss: 0.0014 - val_mae: 0.0369
# Epoch 43/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0011 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0381
# Epoch 44/500
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0011 - mae: 0.0341 - val_loss: 0.0014 - val_mae: 0.0368
# Epoch 45/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0011 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0376
# Epoch 46/500
# 33/33 [==============================] - 1s 25ms/step - loss: 0.0011 - mae: 0.0345 - val_loss: 0.0015 - val_mae: 0.0413
# Epoch 47/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0011 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0364
# Epoch 48/500
# 33/33 [==============================] - 1s 28ms/step - loss: 0.0011 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0377
# Epoch 49/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0011 - mae: 0.0332 - val_loss: 0.0014 - val_mae: 0.0388
# Epoch 50/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0010 - mae: 0.0333 - val_loss: 0.0013 - val_mae: 0.0354
# Epoch 51/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0010 - mae: 0.0332 - val_loss: 0.0014 - val_mae: 0.0374
# Epoch 52/500
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0010 - mae: 0.0333 - val_loss: 0.0015 - val_mae: 0.0404
# Epoch 53/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0010 - mae: 0.0328 - val_loss: 0.0014 - val_mae: 0.0386
# Epoch 54/500
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0010 - mae: 0.0327 - val_loss: 0.0014 - val_mae: 0.0389
# Epoch 55/500
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0010 - mae: 0.0324 - val_loss: 0.0013 - val_mae: 0.0357
# Epoch 56/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.9918e-04 - mae: 0.0321 - val_loss: 0.0015 - val_mae: 0.0396
# Epoch 57/500
# 33/33 [==============================] - 1s 22ms/step - loss: 9.9914e-04 - mae: 0.0322 - val_loss: 0.0013 - val_mae: 0.0354
# Epoch 58/500
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0010 - mae: 0.0325 - val_loss: 0.0013 - val_mae: 0.0348
# Epoch 59/500
# 33/33 [==============================] - 1s 25ms/step - loss: 9.8088e-04 - mae: 0.0320 - val_loss: 0.0013 - val_mae: 0.0349
# Epoch 60/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.7258e-04 - mae: 0.0320 - val_loss: 0.0013 - val_mae: 0.0346
# Epoch 61/500
# 33/33 [==============================] - 1s 24ms/step - loss: 9.7985e-04 - mae: 0.0320 - val_loss: 0.0013 - val_mae: 0.0345
# Epoch 62/500
# 33/33 [==============================] - 1s 24ms/step - loss: 9.6445e-04 - mae: 0.0316 - val_loss: 0.0013 - val_mae: 0.0359
# Epoch 63/500
# 33/33 [==============================] - 1s 24ms/step - loss: 9.5723e-04 - mae: 0.0314 - val_loss: 0.0013 - val_mae: 0.0342
# Epoch 64/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.5870e-04 - mae: 0.0315 - val_loss: 0.0013 - val_mae: 0.0343
# Epoch 65/500
# 33/33 [==============================] - 1s 22ms/step - loss: 9.7880e-04 - mae: 0.0323 - val_loss: 0.0012 - val_mae: 0.0335
# Epoch 66/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.5595e-04 - mae: 0.0317 - val_loss: 0.0012 - val_mae: 0.0335
# Epoch 67/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.3658e-04 - mae: 0.0313 - val_loss: 0.0012 - val_mae: 0.0339
# Epoch 68/500
# 33/33 [==============================] - 1s 22ms/step - loss: 9.4829e-04 - mae: 0.0311 - val_loss: 0.0014 - val_mae: 0.0385
# Epoch 69/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.8457e-04 - mae: 0.0321 - val_loss: 0.0014 - val_mae: 0.0374
# Epoch 70/500
# 33/33 [==============================] - 1s 21ms/step - loss: 9.2719e-04 - mae: 0.0310 - val_loss: 0.0012 - val_mae: 0.0336
# Epoch 71/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.3067e-04 - mae: 0.0308 - val_loss: 0.0014 - val_mae: 0.0374
# Epoch 72/500
# 33/33 [==============================] - 1s 25ms/step - loss: 9.1060e-04 - mae: 0.0305 - val_loss: 0.0012 - val_mae: 0.0329
# Epoch 73/500
# 33/33 [==============================] - 1s 26ms/step - loss: 9.0895e-04 - mae: 0.0306 - val_loss: 0.0012 - val_mae: 0.0340
# Epoch 74/500
# 33/33 [==============================] - 1s 25ms/step - loss: 9.2577e-04 - mae: 0.0310 - val_loss: 0.0012 - val_mae: 0.0333
# Epoch 75/500
# 33/33 [==============================] - 1s 26ms/step - loss: 9.1374e-04 - mae: 0.0306 - val_loss: 0.0012 - val_mae: 0.0345
# Epoch 76/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.0569e-04 - mae: 0.0307 - val_loss: 0.0012 - val_mae: 0.0322
# Epoch 77/500
# 33/33 [==============================] - 1s 23ms/step - loss: 9.0407e-04 - mae: 0.0303 - val_loss: 0.0012 - val_mae: 0.0337
# Epoch 78/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.7759e-04 - mae: 0.0299 - val_loss: 0.0012 - val_mae: 0.0327
# Epoch 79/500
# 33/33 [==============================] - 1s 22ms/step - loss: 8.9408e-04 - mae: 0.0305 - val_loss: 0.0012 - val_mae: 0.0319
# Epoch 80/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.8391e-04 - mae: 0.0301 - val_loss: 0.0012 - val_mae: 0.0320
# Epoch 81/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.8002e-04 - mae: 0.0300 - val_loss: 0.0013 - val_mae: 0.0348
# Epoch 82/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.8030e-04 - mae: 0.0297 - val_loss: 0.0012 - val_mae: 0.0331
# Epoch 83/500
# 33/33 [==============================] - 1s 29ms/step - loss: 8.6726e-04 - mae: 0.0298 - val_loss: 0.0012 - val_mae: 0.0315
# Epoch 84/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.7335e-04 - mae: 0.0299 - val_loss: 0.0012 - val_mae: 0.0315
# Epoch 85/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.6931e-04 - mae: 0.0298 - val_loss: 0.0013 - val_mae: 0.0349
# Epoch 86/500
# 33/33 [==============================] - 1s 28ms/step - loss: 8.5329e-04 - mae: 0.0294 - val_loss: 0.0012 - val_mae: 0.0323
# Epoch 87/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.5330e-04 - mae: 0.0295 - val_loss: 0.0012 - val_mae: 0.0312
# Epoch 88/500
# 33/33 [==============================] - 1s 26ms/step - loss: 8.7283e-04 - mae: 0.0303 - val_loss: 0.0011 - val_mae: 0.0312
# Epoch 89/500
# 33/33 [==============================] - 1s 26ms/step - loss: 8.4140e-04 - mae: 0.0294 - val_loss: 0.0012 - val_mae: 0.0317
# Epoch 90/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.5671e-04 - mae: 0.0294 - val_loss: 0.0013 - val_mae: 0.0352
# Epoch 91/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.4670e-04 - mae: 0.0292 - val_loss: 0.0012 - val_mae: 0.0332
# Epoch 92/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.3437e-04 - mae: 0.0289 - val_loss: 0.0012 - val_mae: 0.0331
# Epoch 93/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.4299e-04 - mae: 0.0292 - val_loss: 0.0011 - val_mae: 0.0309
# Epoch 94/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.3525e-04 - mae: 0.0289 - val_loss: 0.0013 - val_mae: 0.0360
# Epoch 95/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.5029e-04 - mae: 0.0294 - val_loss: 0.0012 - val_mae: 0.0321
# Epoch 96/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.2800e-04 - mae: 0.0288 - val_loss: 0.0012 - val_mae: 0.0337
# Epoch 97/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.3581e-04 - mae: 0.0289 - val_loss: 0.0011 - val_mae: 0.0314
# Epoch 98/500
# 33/33 [==============================] - 1s 26ms/step - loss: 8.3094e-04 - mae: 0.0289 - val_loss: 0.0012 - val_mae: 0.0320
# Epoch 99/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.1446e-04 - mae: 0.0286 - val_loss: 0.0011 - val_mae: 0.0307
# Epoch 100/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.0771e-04 - mae: 0.0285 - val_loss: 0.0011 - val_mae: 0.0306
# Epoch 101/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.1945e-04 - mae: 0.0286 - val_loss: 0.0012 - val_mae: 0.0320
# Epoch 102/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.1519e-04 - mae: 0.0286 - val_loss: 0.0011 - val_mae: 0.0315
# Epoch 103/500
# 33/33 [==============================] - 1s 25ms/step - loss: 8.1121e-04 - mae: 0.0286 - val_loss: 0.0011 - val_mae: 0.0314
# Epoch 104/500
# 33/33 [==============================] - 1s 26ms/step - loss: 8.0630e-04 - mae: 0.0282 - val_loss: 0.0011 - val_mae: 0.0298
# Epoch 105/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.1631e-04 - mae: 0.0285 - val_loss: 0.0012 - val_mae: 0.0335
# Epoch 106/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.1403e-04 - mae: 0.0283 - val_loss: 0.0011 - val_mae: 0.0316
# Epoch 107/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.1265e-04 - mae: 0.0285 - val_loss: 0.0013 - val_mae: 0.0358
# Epoch 108/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.1978e-04 - mae: 0.0288 - val_loss: 0.0011 - val_mae: 0.0314
# Epoch 109/500
# 33/33 [==============================] - 1s 24ms/step - loss: 8.0130e-04 - mae: 0.0280 - val_loss: 0.0011 - val_mae: 0.0306
# Epoch 110/500
# 33/33 [==============================] - 1s 29ms/step - loss: 7.9111e-04 - mae: 0.0279 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 111/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.9074e-04 - mae: 0.0279 - val_loss: 0.0011 - val_mae: 0.0305
# Epoch 112/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.8707e-04 - mae: 0.0280 - val_loss: 0.0012 - val_mae: 0.0327
# Epoch 113/500
# 33/33 [==============================] - 1s 23ms/step - loss: 8.1577e-04 - mae: 0.0285 - val_loss: 0.0012 - val_mae: 0.0322
# Epoch 114/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.8817e-04 - mae: 0.0280 - val_loss: 0.0011 - val_mae: 0.0305
# Epoch 115/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.6973e-04 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0291
# Epoch 116/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.9140e-04 - mae: 0.0283 - val_loss: 0.0011 - val_mae: 0.0292
# Epoch 117/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.7451e-04 - mae: 0.0275 - val_loss: 0.0011 - val_mae: 0.0290
# Epoch 118/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.8856e-04 - mae: 0.0279 - val_loss: 0.0011 - val_mae: 0.0304
# Epoch 119/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.7896e-04 - mae: 0.0276 - val_loss: 0.0011 - val_mae: 0.0297
# Epoch 120/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.7266e-04 - mae: 0.0276 - val_loss: 0.0011 - val_mae: 0.0292
# Epoch 121/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.5982e-04 - mae: 0.0273 - val_loss: 0.0011 - val_mae: 0.0316
# Epoch 122/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.6690e-04 - mae: 0.0273 - val_loss: 0.0012 - val_mae: 0.0319
# Epoch 123/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.5883e-04 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0286
# Epoch 124/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.8463e-04 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0295
# Epoch 125/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.6131e-04 - mae: 0.0274 - val_loss: 0.0011 - val_mae: 0.0305
# Epoch 126/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.6606e-04 - mae: 0.0273 - val_loss: 0.0011 - val_mae: 0.0313
# Epoch 127/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.5250e-04 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0302
# Epoch 128/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.5112e-04 - mae: 0.0269 - val_loss: 0.0011 - val_mae: 0.0290
# Epoch 129/500
# 33/33 [==============================] - 1s 27ms/step - loss: 7.4088e-04 - mae: 0.0270 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 130/500
# 33/33 [==============================] - 1s 28ms/step - loss: 7.4781e-04 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0302
# Epoch 131/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.4304e-04 - mae: 0.0268 - val_loss: 0.0012 - val_mae: 0.0318
# Epoch 132/500
# 33/33 [==============================] - 1s 26ms/step - loss: 7.5344e-04 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0295
# Epoch 133/500
# 33/33 [==============================] - 1s 26ms/step - loss: 7.4545e-04 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0279
# Epoch 134/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.4622e-04 - mae: 0.0270 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 135/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.4952e-04 - mae: 0.0272 - val_loss: 0.0012 - val_mae: 0.0331
# Epoch 136/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.5275e-04 - mae: 0.0272 - val_loss: 0.0011 - val_mae: 0.0308
# Epoch 137/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.4190e-04 - mae: 0.0267 - val_loss: 0.0011 - val_mae: 0.0285
# Epoch 138/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.2748e-04 - mae: 0.0265 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 139/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.7857e-04 - mae: 0.0276 - val_loss: 0.0011 - val_mae: 0.0310
# Epoch 140/500
# 33/33 [==============================] - 1s 26ms/step - loss: 7.4493e-04 - mae: 0.0270 - val_loss: 0.0011 - val_mae: 0.0300
# Epoch 141/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.5717e-04 - mae: 0.0272 - val_loss: 0.0011 - val_mae: 0.0312
# Epoch 142/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.5270e-04 - mae: 0.0270 - val_loss: 0.0012 - val_mae: 0.0332
# Epoch 143/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.4194e-04 - mae: 0.0269 - val_loss: 0.0011 - val_mae: 0.0293
# Epoch 144/500
# 33/33 [==============================] - 1s 27ms/step - loss: 7.3541e-04 - mae: 0.0267 - val_loss: 0.0011 - val_mae: 0.0302
# Epoch 145/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.4488e-04 - mae: 0.0266 - val_loss: 0.0010 - val_mae: 0.0278
# Epoch 146/500
# 33/33 [==============================] - 1s 25ms/step - loss: 7.2604e-04 - mae: 0.0263 - val_loss: 0.0010 - val_mae: 0.0277
# Epoch 147/500
# 33/33 [==============================] - 1s 27ms/step - loss: 7.2682e-04 - mae: 0.0264 - val_loss: 0.0011 - val_mae: 0.0283
# Epoch 148/500
# 33/33 [==============================] - 1s 28ms/step - loss: 7.3612e-04 - mae: 0.0264 - val_loss: 0.0011 - val_mae: 0.0289
# Epoch 149/500
# 33/33 [==============================] - 1s 26ms/step - loss: 7.2069e-04 - mae: 0.0262 - val_loss: 0.0010 - val_mae: 0.0281
# Epoch 150/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.2573e-04 - mae: 0.0264 - val_loss: 0.0010 - val_mae: 0.0282
# Epoch 151/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.1802e-04 - mae: 0.0261 - val_loss: 0.0010 - val_mae: 0.0278
# Epoch 152/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.1788e-04 - mae: 0.0261 - val_loss: 0.0010 - val_mae: 0.0271
# Epoch 153/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.2671e-04 - mae: 0.0266 - val_loss: 0.0011 - val_mae: 0.0293
# Epoch 154/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.2135e-04 - mae: 0.0263 - val_loss: 0.0011 - val_mae: 0.0290
# Epoch 155/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.1013e-04 - mae: 0.0260 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 156/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.2668e-04 - mae: 0.0263 - val_loss: 0.0010 - val_mae: 0.0275
# Epoch 157/500
# 33/33 [==============================] - 1s 21ms/step - loss: 7.1862e-04 - mae: 0.0262 - val_loss: 0.0011 - val_mae: 0.0299
# Epoch 158/500
# 33/33 [==============================] - 1s 21ms/step - loss: 7.2263e-04 - mae: 0.0264 - val_loss: 0.0010 - val_mae: 0.0277
# Epoch 159/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.2246e-04 - mae: 0.0262 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 160/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.3358e-04 - mae: 0.0265 - val_loss: 0.0011 - val_mae: 0.0298
# Epoch 161/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.2100e-04 - mae: 0.0263 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 162/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.1017e-04 - mae: 0.0260 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 163/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.1653e-04 - mae: 0.0261 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 164/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.0554e-04 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 165/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.0924e-04 - mae: 0.0258 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 166/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.2825e-04 - mae: 0.0264 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 167/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.3263e-04 - mae: 0.0269 - val_loss: 0.0011 - val_mae: 0.0314
# Epoch 168/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.1067e-04 - mae: 0.0260 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 169/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.0231e-04 - mae: 0.0256 - val_loss: 0.0010 - val_mae: 0.0284
# Epoch 170/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.0211e-04 - mae: 0.0260 - val_loss: 0.0011 - val_mae: 0.0289
# Epoch 171/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.0330e-04 - mae: 0.0259 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 172/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.9645e-04 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0266
# Epoch 173/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.9737e-04 - mae: 0.0258 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 174/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.0364e-04 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0284
# Epoch 175/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.0351e-04 - mae: 0.0259 - val_loss: 0.0010 - val_mae: 0.0265
# Epoch 176/500
# 33/33 [==============================] - 1s 26ms/step - loss: 7.0046e-04 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 177/500
# 33/33 [==============================] - 1s 23ms/step - loss: 7.0617e-04 - mae: 0.0258 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 178/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.9699e-04 - mae: 0.0256 - val_loss: 0.0010 - val_mae: 0.0265
# Epoch 179/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.9727e-04 - mae: 0.0256 - val_loss: 0.0010 - val_mae: 0.0266
# Epoch 180/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.9301e-04 - mae: 0.0255 - val_loss: 0.0010 - val_mae: 0.0283
# Epoch 181/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.0961e-04 - mae: 0.0259 - val_loss: 0.0010 - val_mae: 0.0278
# Epoch 182/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.9563e-04 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0271
# Epoch 183/500
# 33/33 [==============================] - 1s 24ms/step - loss: 7.0250e-04 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0263
# Epoch 184/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.8483e-04 - mae: 0.0252 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 185/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.8594e-04 - mae: 0.0251 - val_loss: 0.0010 - val_mae: 0.0263
# Epoch 186/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.9987e-04 - mae: 0.0255 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 187/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.8742e-04 - mae: 0.0256 - val_loss: 0.0010 - val_mae: 0.0262
# Epoch 188/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8376e-04 - mae: 0.0251 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 189/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.9097e-04 - mae: 0.0254 - val_loss: 0.0011 - val_mae: 0.0285
# Epoch 190/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.9279e-04 - mae: 0.0255 - val_loss: 0.0010 - val_mae: 0.0279
# Epoch 191/500
# 33/33 [==============================] - 1s 28ms/step - loss: 6.8992e-04 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 192/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8876e-04 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 193/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.8372e-04 - mae: 0.0253 - val_loss: 0.0010 - val_mae: 0.0284
# Epoch 194/500
# 33/33 [==============================] - 1s 28ms/step - loss: 6.9980e-04 - mae: 0.0256 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 195/500
# 33/33 [==============================] - 1s 30ms/step - loss: 6.8492e-04 - mae: 0.0253 - val_loss: 0.0010 - val_mae: 0.0275
# Epoch 196/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.8947e-04 - mae: 0.0254 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 197/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.8682e-04 - mae: 0.0253 - val_loss: 0.0010 - val_mae: 0.0283
# Epoch 198/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.8292e-04 - mae: 0.0249 - val_loss: 0.0011 - val_mae: 0.0293
# Epoch 199/500
# 33/33 [==============================] - 1s 26ms/step - loss: 7.0363e-04 - mae: 0.0260 - val_loss: 0.0010 - val_mae: 0.0281
# Epoch 200/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.7211e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0275
# Epoch 201/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.7530e-04 - mae: 0.0249 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 202/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.7799e-04 - mae: 0.0252 - val_loss: 0.0010 - val_mae: 0.0259
# Epoch 203/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.7336e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 204/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.6893e-04 - mae: 0.0249 - val_loss: 0.0010 - val_mae: 0.0257
# Epoch 205/500
# 33/33 [==============================] - 1s 22ms/step - loss: 7.0206e-04 - mae: 0.0261 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 206/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8839e-04 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0281
# Epoch 207/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6995e-04 - mae: 0.0247 - val_loss: 0.0010 - val_mae: 0.0282
# Epoch 208/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.7494e-04 - mae: 0.0252 - val_loss: 0.0011 - val_mae: 0.0289
# Epoch 209/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.6714e-04 - mae: 0.0246 - val_loss: 9.9673e-04 - val_mae: 0.0258
# Epoch 210/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.6623e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0256
# Epoch 211/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8752e-04 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0261
# Epoch 212/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.9008e-04 - mae: 0.0257 - val_loss: 0.0010 - val_mae: 0.0265
# Epoch 213/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.6630e-04 - mae: 0.0246 - val_loss: 0.0011 - val_mae: 0.0284
# Epoch 214/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.6949e-04 - mae: 0.0247 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 215/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.6359e-04 - mae: 0.0246 - val_loss: 0.0010 - val_mae: 0.0278
# Epoch 216/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.7707e-04 - mae: 0.0251 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 217/500
# 33/33 [==============================] - 1s 28ms/step - loss: 6.7498e-04 - mae: 0.0251 - val_loss: 9.9460e-04 - val_mae: 0.0255
# Epoch 218/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.7031e-04 - mae: 0.0251 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 219/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8770e-04 - mae: 0.0253 - val_loss: 0.0010 - val_mae: 0.0275
# Epoch 220/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.7373e-04 - mae: 0.0249 - val_loss: 0.0010 - val_mae: 0.0276
# Epoch 221/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.7592e-04 - mae: 0.0249 - val_loss: 9.9285e-04 - val_mae: 0.0257
# Epoch 222/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6876e-04 - mae: 0.0247 - val_loss: 9.9273e-04 - val_mae: 0.0257
# Epoch 223/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6274e-04 - mae: 0.0247 - val_loss: 0.0010 - val_mae: 0.0259
# Epoch 224/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.7936e-04 - mae: 0.0251 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 225/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.6010e-04 - mae: 0.0244 - val_loss: 9.9256e-04 - val_mae: 0.0253
# Epoch 226/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6079e-04 - mae: 0.0246 - val_loss: 9.9027e-04 - val_mae: 0.0255
# Epoch 227/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.6132e-04 - mae: 0.0246 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 228/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6919e-04 - mae: 0.0249 - val_loss: 0.0011 - val_mae: 0.0290
# Epoch 229/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.7763e-04 - mae: 0.0249 - val_loss: 9.9488e-04 - val_mae: 0.0259
# Epoch 230/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.6674e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 231/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8265e-04 - mae: 0.0253 - val_loss: 9.9156e-04 - val_mae: 0.0257
# Epoch 232/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.6850e-04 - mae: 0.0249 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 233/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.7379e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 234/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5521e-04 - mae: 0.0245 - val_loss: 9.9722e-04 - val_mae: 0.0261
# Epoch 235/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.6182e-04 - mae: 0.0246 - val_loss: 9.8965e-04 - val_mae: 0.0256
# Epoch 236/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.6877e-04 - mae: 0.0247 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 237/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5361e-04 - mae: 0.0244 - val_loss: 9.8547e-04 - val_mae: 0.0253
# Epoch 238/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5504e-04 - mae: 0.0242 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 239/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5297e-04 - mae: 0.0243 - val_loss: 0.0011 - val_mae: 0.0282
# Epoch 240/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.5980e-04 - mae: 0.0245 - val_loss: 0.0010 - val_mae: 0.0275
# Epoch 241/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5420e-04 - mae: 0.0244 - val_loss: 9.9121e-04 - val_mae: 0.0257
# Epoch 242/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.8191e-04 - mae: 0.0250 - val_loss: 0.0011 - val_mae: 0.0292
# Epoch 243/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.5758e-04 - mae: 0.0244 - val_loss: 0.0010 - val_mae: 0.0272
# Epoch 244/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6082e-04 - mae: 0.0244 - val_loss: 0.0011 - val_mae: 0.0285
# Epoch 245/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5750e-04 - mae: 0.0246 - val_loss: 9.9816e-04 - val_mae: 0.0262
# Epoch 246/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.6432e-04 - mae: 0.0246 - val_loss: 0.0012 - val_mae: 0.0324
# Epoch 247/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.7651e-04 - mae: 0.0250 - val_loss: 0.0010 - val_mae: 0.0272
# Epoch 248/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.6258e-04 - mae: 0.0244 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 249/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4925e-04 - mae: 0.0242 - val_loss: 0.0010 - val_mae: 0.0253
# Epoch 250/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.9140e-04 - mae: 0.0256 - val_loss: 9.8097e-04 - val_mae: 0.0251
# Epoch 251/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.6134e-04 - mae: 0.0247 - val_loss: 9.7996e-04 - val_mae: 0.0251
# Epoch 252/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.7106e-04 - mae: 0.0250 - val_loss: 0.0012 - val_mae: 0.0316
# Epoch 253/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.8454e-04 - mae: 0.0254 - val_loss: 0.0013 - val_mae: 0.0345
# Epoch 254/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.9349e-04 - mae: 0.0253 - val_loss: 0.0011 - val_mae: 0.0290
# Epoch 255/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.5894e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0274
# Epoch 256/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.7201e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0276
# Epoch 257/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5027e-04 - mae: 0.0242 - val_loss: 9.8610e-04 - val_mae: 0.0249
# Epoch 258/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4817e-04 - mae: 0.0242 - val_loss: 9.9808e-04 - val_mae: 0.0252
# Epoch 259/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5482e-04 - mae: 0.0244 - val_loss: 9.8999e-04 - val_mae: 0.0258
# Epoch 260/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5198e-04 - mae: 0.0244 - val_loss: 9.8180e-04 - val_mae: 0.0253
# Epoch 261/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.5084e-04 - mae: 0.0243 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 262/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.6379e-04 - mae: 0.0245 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 263/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.4215e-04 - mae: 0.0239 - val_loss: 9.7815e-04 - val_mae: 0.0248
# Epoch 264/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.6078e-04 - mae: 0.0245 - val_loss: 9.8468e-04 - val_mae: 0.0256
# Epoch 265/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.5552e-04 - mae: 0.0243 - val_loss: 9.9274e-04 - val_mae: 0.0259
# Epoch 266/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5985e-04 - mae: 0.0244 - val_loss: 9.8263e-04 - val_mae: 0.0254
# Epoch 267/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4071e-04 - mae: 0.0240 - val_loss: 9.7676e-04 - val_mae: 0.0250
# Epoch 268/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4551e-04 - mae: 0.0240 - val_loss: 9.7551e-04 - val_mae: 0.0248
# Epoch 269/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4173e-04 - mae: 0.0241 - val_loss: 9.7621e-04 - val_mae: 0.0249
# Epoch 270/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4577e-04 - mae: 0.0240 - val_loss: 9.7669e-04 - val_mae: 0.0250
# Epoch 271/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.4870e-04 - mae: 0.0241 - val_loss: 9.7779e-04 - val_mae: 0.0250
# Epoch 272/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.4850e-04 - mae: 0.0242 - val_loss: 9.9704e-04 - val_mae: 0.0261
# Epoch 273/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.4720e-04 - mae: 0.0240 - val_loss: 9.8217e-04 - val_mae: 0.0254
# Epoch 274/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.4496e-04 - mae: 0.0241 - val_loss: 0.0010 - val_mae: 0.0263
# Epoch 275/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.5502e-04 - mae: 0.0244 - val_loss: 0.0010 - val_mae: 0.0263
# Epoch 276/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.3810e-04 - mae: 0.0239 - val_loss: 9.7948e-04 - val_mae: 0.0247
# Epoch 277/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4912e-04 - mae: 0.0239 - val_loss: 0.0010 - val_mae: 0.0262
# Epoch 278/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4183e-04 - mae: 0.0240 - val_loss: 9.9989e-04 - val_mae: 0.0253
# Epoch 279/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5451e-04 - mae: 0.0244 - val_loss: 9.8062e-04 - val_mae: 0.0248
# Epoch 280/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.4617e-04 - mae: 0.0241 - val_loss: 9.7852e-04 - val_mae: 0.0252
# Epoch 281/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5762e-04 - mae: 0.0247 - val_loss: 0.0010 - val_mae: 0.0272
# Epoch 282/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4808e-04 - mae: 0.0240 - val_loss: 9.9256e-04 - val_mae: 0.0258
# Epoch 283/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.6238e-04 - mae: 0.0245 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 284/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5742e-04 - mae: 0.0245 - val_loss: 9.7351e-04 - val_mae: 0.0248
# Epoch 285/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4610e-04 - mae: 0.0239 - val_loss: 9.9359e-04 - val_mae: 0.0259
# Epoch 286/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5645e-04 - mae: 0.0242 - val_loss: 9.8871e-04 - val_mae: 0.0257
# Epoch 287/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.5284e-04 - mae: 0.0242 - val_loss: 9.8575e-04 - val_mae: 0.0256
# Epoch 288/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3923e-04 - mae: 0.0238 - val_loss: 9.7229e-04 - val_mae: 0.0247
# Epoch 289/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3648e-04 - mae: 0.0238 - val_loss: 0.0011 - val_mae: 0.0279
# Epoch 290/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4901e-04 - mae: 0.0242 - val_loss: 9.9249e-04 - val_mae: 0.0259
# Epoch 291/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4464e-04 - mae: 0.0242 - val_loss: 9.7162e-04 - val_mae: 0.0246
# Epoch 292/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.6035e-04 - mae: 0.0244 - val_loss: 9.7116e-04 - val_mae: 0.0247
# Epoch 293/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.3578e-04 - mae: 0.0238 - val_loss: 9.8236e-04 - val_mae: 0.0254
# Epoch 294/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.3353e-04 - mae: 0.0236 - val_loss: 9.7700e-04 - val_mae: 0.0252
# Epoch 295/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3395e-04 - mae: 0.0235 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 296/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3591e-04 - mae: 0.0240 - val_loss: 9.7328e-04 - val_mae: 0.0249
# Epoch 297/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4074e-04 - mae: 0.0238 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 298/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4864e-04 - mae: 0.0241 - val_loss: 9.9067e-04 - val_mae: 0.0257
# Epoch 299/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4593e-04 - mae: 0.0243 - val_loss: 0.0010 - val_mae: 0.0278
# Epoch 300/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.5161e-04 - mae: 0.0243 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 301/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.5343e-04 - mae: 0.0244 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 302/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3603e-04 - mae: 0.0238 - val_loss: 9.7640e-04 - val_mae: 0.0251
# Epoch 303/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3527e-04 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 304/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.4074e-04 - mae: 0.0238 - val_loss: 9.6819e-04 - val_mae: 0.0246
# Epoch 305/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.5372e-04 - mae: 0.0240 - val_loss: 9.6776e-04 - val_mae: 0.0245
# Epoch 306/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.6821e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0255
# Epoch 307/500
# 33/33 [==============================] - 1s 29ms/step - loss: 6.7229e-04 - mae: 0.0243 - val_loss: 9.7715e-04 - val_mae: 0.0251
# Epoch 308/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.3782e-04 - mae: 0.0237 - val_loss: 9.9710e-04 - val_mae: 0.0261
# Epoch 309/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3374e-04 - mae: 0.0237 - val_loss: 9.9012e-04 - val_mae: 0.0257
# Epoch 310/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3554e-04 - mae: 0.0238 - val_loss: 9.7516e-04 - val_mae: 0.0250
# Epoch 311/500
# 33/33 [==============================] - 1s 20ms/step - loss: 6.5245e-04 - mae: 0.0244 - val_loss: 9.8145e-04 - val_mae: 0.0253
# Epoch 312/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.4668e-04 - mae: 0.0241 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 313/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5642e-04 - mae: 0.0244 - val_loss: 9.9983e-04 - val_mae: 0.0261
# Epoch 314/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3307e-04 - mae: 0.0235 - val_loss: 0.0011 - val_mae: 0.0283
# Epoch 315/500
# 33/33 [==============================] - 1s 20ms/step - loss: 6.4538e-04 - mae: 0.0241 - val_loss: 9.6823e-04 - val_mae: 0.0245
# Epoch 316/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.4057e-04 - mae: 0.0241 - val_loss: 9.6600e-04 - val_mae: 0.0244
# Epoch 317/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.3830e-04 - mae: 0.0240 - val_loss: 9.6723e-04 - val_mae: 0.0244
# Epoch 318/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3360e-04 - mae: 0.0236 - val_loss: 9.6605e-04 - val_mae: 0.0246
# Epoch 319/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3414e-04 - mae: 0.0236 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 320/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.5686e-04 - mae: 0.0248 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 321/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3622e-04 - mae: 0.0238 - val_loss: 9.6538e-04 - val_mae: 0.0244
# Epoch 322/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3378e-04 - mae: 0.0237 - val_loss: 9.6457e-04 - val_mae: 0.0245
# Epoch 323/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.4075e-04 - mae: 0.0240 - val_loss: 9.9056e-04 - val_mae: 0.0257
# Epoch 324/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.3544e-04 - mae: 0.0236 - val_loss: 9.7550e-04 - val_mae: 0.0251
# Epoch 325/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.3205e-04 - mae: 0.0235 - val_loss: 9.6871e-04 - val_mae: 0.0244
# Epoch 326/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2986e-04 - mae: 0.0236 - val_loss: 9.8967e-04 - val_mae: 0.0257
# Epoch 327/500
# 33/33 [==============================] - 1s 19ms/step - loss: 6.3690e-04 - mae: 0.0237 - val_loss: 0.0010 - val_mae: 0.0262
# Epoch 328/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3295e-04 - mae: 0.0235 - val_loss: 9.7931e-04 - val_mae: 0.0252
# Epoch 329/500
# 33/33 [==============================] - 1s 20ms/step - loss: 6.2869e-04 - mae: 0.0235 - val_loss: 9.6744e-04 - val_mae: 0.0244
# Epoch 330/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.4800e-04 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0261
# Epoch 331/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.4048e-04 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0277
# Epoch 332/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3486e-04 - mae: 0.0237 - val_loss: 9.9926e-04 - val_mae: 0.0260
# Epoch 333/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.3086e-04 - mae: 0.0235 - val_loss: 9.7475e-04 - val_mae: 0.0251
# Epoch 334/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.4806e-04 - mae: 0.0242 - val_loss: 9.8099e-04 - val_mae: 0.0253
# Epoch 335/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.3204e-04 - mae: 0.0236 - val_loss: 9.9530e-04 - val_mae: 0.0258
# Epoch 336/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.3373e-04 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0272
# Epoch 337/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2623e-04 - mae: 0.0234 - val_loss: 9.6319e-04 - val_mae: 0.0243
# Epoch 338/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2082e-04 - mae: 0.0233 - val_loss: 9.6253e-04 - val_mae: 0.0242
# Epoch 339/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2834e-04 - mae: 0.0236 - val_loss: 9.7284e-04 - val_mae: 0.0249
# Epoch 340/500
# 33/33 [==============================] - 1s 30ms/step - loss: 6.4973e-04 - mae: 0.0245 - val_loss: 0.0011 - val_mae: 0.0297
# Epoch 341/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2675e-04 - mae: 0.0233 - val_loss: 9.6932e-04 - val_mae: 0.0248
# Epoch 342/500
# 33/33 [==============================] - 1s 20ms/step - loss: 6.3369e-04 - mae: 0.0238 - val_loss: 9.6297e-04 - val_mae: 0.0244
# Epoch 343/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.3617e-04 - mae: 0.0236 - val_loss: 0.0010 - val_mae: 0.0265
# Epoch 344/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2918e-04 - mae: 0.0236 - val_loss: 9.6407e-04 - val_mae: 0.0245
# Epoch 345/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.2978e-04 - mae: 0.0236 - val_loss: 9.9286e-04 - val_mae: 0.0257
# Epoch 346/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3238e-04 - mae: 0.0236 - val_loss: 9.8809e-04 - val_mae: 0.0255
# Epoch 347/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2611e-04 - mae: 0.0234 - val_loss: 9.7913e-04 - val_mae: 0.0252
# Epoch 348/500
# ...
# Epoch 388/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1838e-04 - mae: 0.0232 - val_loss: 9.6106e-04 - val_mae: 0.0245
# Epoch 389/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1712e-04 - mae: 0.0231 - val_loss: 9.6171e-04 - val_mae: 0.0245
# Epoch 390/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2201e-04 - mae: 0.0233 - val_loss: 9.5758e-04 - val_mae: 0.0243
# Epoch 391/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3436e-04 - mae: 0.0240 - val_loss: 9.9718e-04 - val_mae: 0.0257
# Epoch 392/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3441e-04 - mae: 0.0236 - val_loss: 9.5756e-04 - val_mae: 0.0241
# Epoch 393/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2228e-04 - mae: 0.0232 - val_loss: 9.5642e-04 - val_mae: 0.0243
# Epoch 394/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1960e-04 - mae: 0.0231 - val_loss: 9.8257e-04 - val_mae: 0.0252
# Epoch 395/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.1950e-04 - mae: 0.0233 - val_loss: 9.5515e-04 - val_mae: 0.0240
# Epoch 396/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2447e-04 - mae: 0.0232 - val_loss: 9.5818e-04 - val_mae: 0.0241
# Epoch 397/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1998e-04 - mae: 0.0232 - val_loss: 9.7818e-04 - val_mae: 0.0250
# Epoch 398/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3392e-04 - mae: 0.0236 - val_loss: 9.5611e-04 - val_mae: 0.0242
# Epoch 399/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.2906e-04 - mae: 0.0236 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 400/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3362e-04 - mae: 0.0235 - val_loss: 9.7524e-04 - val_mae: 0.0248
# Epoch 401/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.1807e-04 - mae: 0.0231 - val_loss: 9.9751e-04 - val_mae: 0.0256
# Epoch 402/500
# 33/33 [==============================] - 1s 29ms/step - loss: 6.5366e-04 - mae: 0.0243 - val_loss: 9.5517e-04 - val_mae: 0.0241
# Epoch 403/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2051e-04 - mae: 0.0232 - val_loss: 9.7015e-04 - val_mae: 0.0247
# Epoch 404/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2730e-04 - mae: 0.0233 - val_loss: 9.6030e-04 - val_mae: 0.0241
# Epoch 405/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1921e-04 - mae: 0.0232 - val_loss: 9.6827e-04 - val_mae: 0.0247
# Epoch 406/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.2016e-04 - mae: 0.0232 - val_loss: 9.9014e-04 - val_mae: 0.0254
# Epoch 407/500
# 33/33 [==============================] - 1s 30ms/step - loss: 6.2306e-04 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 408/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.2992e-04 - mae: 0.0233 - val_loss: 9.8128e-04 - val_mae: 0.0251
# Epoch 409/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1992e-04 - mae: 0.0232 - val_loss: 9.7247e-04 - val_mae: 0.0248
# Epoch 410/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1722e-04 - mae: 0.0230 - val_loss: 9.7292e-04 - val_mae: 0.0247
# Epoch 411/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1569e-04 - mae: 0.0232 - val_loss: 9.6906e-04 - val_mae: 0.0247
# Epoch 412/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1527e-04 - mae: 0.0231 - val_loss: 9.5745e-04 - val_mae: 0.0244
# Epoch 413/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.1587e-04 - mae: 0.0231 - val_loss: 9.7050e-04 - val_mae: 0.0248
# Epoch 414/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.3698e-04 - mae: 0.0237 - val_loss: 0.0011 - val_mae: 0.0292
# Epoch 415/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2888e-04 - mae: 0.0235 - val_loss: 9.8862e-04 - val_mae: 0.0254
# Epoch 416/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1723e-04 - mae: 0.0232 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 417/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2485e-04 - mae: 0.0234 - val_loss: 9.9863e-04 - val_mae: 0.0256
# Epoch 418/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.4628e-04 - mae: 0.0241 - val_loss: 0.0011 - val_mae: 0.0284
# Epoch 419/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2215e-04 - mae: 0.0233 - val_loss: 9.9731e-04 - val_mae: 0.0256
# Epoch 420/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2233e-04 - mae: 0.0233 - val_loss: 9.5813e-04 - val_mae: 0.0242
# Epoch 421/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2031e-04 - mae: 0.0231 - val_loss: 0.0010 - val_mae: 0.0270
# Epoch 422/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3708e-04 - mae: 0.0235 - val_loss: 9.6386e-04 - val_mae: 0.0246
# Epoch 423/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2207e-04 - mae: 0.0234 - val_loss: 9.6182e-04 - val_mae: 0.0244
# Epoch 424/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.2685e-04 - mae: 0.0236 - val_loss: 9.8933e-04 - val_mae: 0.0253
# Epoch 425/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2183e-04 - mae: 0.0232 - val_loss: 9.9628e-04 - val_mae: 0.0255
# Epoch 426/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.4806e-04 - mae: 0.0239 - val_loss: 9.5382e-04 - val_mae: 0.0241
# Epoch 427/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5674e-04 - mae: 0.0246 - val_loss: 9.5314e-04 - val_mae: 0.0240
# Epoch 428/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.4186e-04 - mae: 0.0237 - val_loss: 0.0011 - val_mae: 0.0277
# Epoch 429/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2364e-04 - mae: 0.0233 - val_loss: 9.7118e-04 - val_mae: 0.0247
# Epoch 430/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.2952e-04 - mae: 0.0232 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 431/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4350e-04 - mae: 0.0240 - val_loss: 9.5871e-04 - val_mae: 0.0241
# Epoch 432/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.3333e-04 - mae: 0.0239 - val_loss: 9.6230e-04 - val_mae: 0.0245
# Epoch 433/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1877e-04 - mae: 0.0232 - val_loss: 9.5979e-04 - val_mae: 0.0244
# Epoch 434/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1709e-04 - mae: 0.0231 - val_loss: 9.5146e-04 - val_mae: 0.0240
# Epoch 435/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1934e-04 - mae: 0.0231 - val_loss: 0.0010 - val_mae: 0.0265
# Epoch 436/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2902e-04 - mae: 0.0233 - val_loss: 9.7552e-04 - val_mae: 0.0248
# Epoch 437/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2534e-04 - mae: 0.0237 - val_loss: 9.5374e-04 - val_mae: 0.0241
# Epoch 438/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2657e-04 - mae: 0.0234 - val_loss: 9.6748e-04 - val_mae: 0.0245
# Epoch 439/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1447e-04 - mae: 0.0229 - val_loss: 9.5459e-04 - val_mae: 0.0240
# Epoch 440/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.2170e-04 - mae: 0.0234 - val_loss: 9.5354e-04 - val_mae: 0.0241
# Epoch 441/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.2262e-04 - mae: 0.0233 - val_loss: 9.7042e-04 - val_mae: 0.0247
# Epoch 442/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2766e-04 - mae: 0.0235 - val_loss: 9.6897e-04 - val_mae: 0.0244
# Epoch 443/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.3012e-04 - mae: 0.0234 - val_loss: 9.5081e-04 - val_mae: 0.0240
# Epoch 444/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2548e-04 - mae: 0.0235 - val_loss: 9.8405e-04 - val_mae: 0.0251
# Epoch 445/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2457e-04 - mae: 0.0233 - val_loss: 9.9155e-04 - val_mae: 0.0253
# Epoch 446/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.3579e-04 - mae: 0.0238 - val_loss: 9.5453e-04 - val_mae: 0.0241
# Epoch 447/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.5079e-04 - mae: 0.0243 - val_loss: 9.5057e-04 - val_mae: 0.0239
# Epoch 448/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2225e-04 - mae: 0.0231 - val_loss: 9.5054e-04 - val_mae: 0.0239
# Epoch 449/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.1394e-04 - mae: 0.0231 - val_loss: 9.5498e-04 - val_mae: 0.0242
# Epoch 450/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.1017e-04 - mae: 0.0229 - val_loss: 9.6517e-04 - val_mae: 0.0245
# Epoch 451/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1754e-04 - mae: 0.0232 - val_loss: 9.8734e-04 - val_mae: 0.0252
# Epoch 452/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.3181e-04 - mae: 0.0235 - val_loss: 0.0010 - val_mae: 0.0261
# Epoch 453/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4085e-04 - mae: 0.0238 - val_loss: 9.9718e-04 - val_mae: 0.0256
# Epoch 454/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.3283e-04 - mae: 0.0235 - val_loss: 0.0011 - val_mae: 0.0283
# Epoch 455/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2110e-04 - mae: 0.0230 - val_loss: 9.6872e-04 - val_mae: 0.0246
# Epoch 456/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2608e-04 - mae: 0.0234 - val_loss: 0.0011 - val_mae: 0.0286
# Epoch 457/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.2880e-04 - mae: 0.0234 - val_loss: 9.5686e-04 - val_mae: 0.0242
# Epoch 458/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.1615e-04 - mae: 0.0230 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 459/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.1410e-04 - mae: 0.0229 - val_loss: 9.5870e-04 - val_mae: 0.0241
# Epoch 460/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2061e-04 - mae: 0.0232 - val_loss: 9.9637e-04 - val_mae: 0.0255
# Epoch 461/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1415e-04 - mae: 0.0230 - val_loss: 9.5065e-04 - val_mae: 0.0240
# Epoch 462/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1367e-04 - mae: 0.0229 - val_loss: 9.5415e-04 - val_mae: 0.0241
# Epoch 463/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2585e-04 - mae: 0.0236 - val_loss: 9.5186e-04 - val_mae: 0.0241
# Epoch 464/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2036e-04 - mae: 0.0231 - val_loss: 9.5200e-04 - val_mae: 0.0241
# Epoch 465/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.1651e-04 - mae: 0.0230 - val_loss: 9.4912e-04 - val_mae: 0.0239
# Epoch 466/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1268e-04 - mae: 0.0230 - val_loss: 0.0010 - val_mae: 0.0260
# Epoch 467/500
# 33/33 [==============================] - 1s 32ms/step - loss: 6.1982e-04 - mae: 0.0231 - val_loss: 9.6496e-04 - val_mae: 0.0245
# Epoch 468/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1412e-04 - mae: 0.0231 - val_loss: 9.7186e-04 - val_mae: 0.0247
# Epoch 469/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1673e-04 - mae: 0.0232 - val_loss: 9.5420e-04 - val_mae: 0.0242
# Epoch 470/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.3477e-04 - mae: 0.0236 - val_loss: 9.4929e-04 - val_mae: 0.0239
# Epoch 471/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1708e-04 - mae: 0.0228 - val_loss: 0.0010 - val_mae: 0.0256
# Epoch 472/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2226e-04 - mae: 0.0233 - val_loss: 9.6920e-04 - val_mae: 0.0247
# Epoch 473/500
# 33/33 [==============================] - 1s 26ms/step - loss: 6.2485e-04 - mae: 0.0235 - val_loss: 9.7228e-04 - val_mae: 0.0248
# Epoch 474/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.0851e-04 - mae: 0.0230 - val_loss: 9.4974e-04 - val_mae: 0.0240
# Epoch 475/500
# 33/33 [==============================] - 1s 27ms/step - loss: 6.2546e-04 - mae: 0.0232 - val_loss: 9.9897e-04 - val_mae: 0.0256
# Epoch 476/500
# 33/33 [==============================] - 1s 25ms/step - loss: 6.1491e-04 - mae: 0.0231 - val_loss: 9.5801e-04 - val_mae: 0.0242
# Epoch 477/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1765e-04 - mae: 0.0234 - val_loss: 9.8530e-04 - val_mae: 0.0251
# Epoch 478/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2084e-04 - mae: 0.0233 - val_loss: 9.5621e-04 - val_mae: 0.0241
# Epoch 479/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1472e-04 - mae: 0.0230 - val_loss: 9.5179e-04 - val_mae: 0.0241
# Epoch 480/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1605e-04 - mae: 0.0231 - val_loss: 9.6070e-04 - val_mae: 0.0243
# Epoch 481/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1368e-04 - mae: 0.0230 - val_loss: 9.6557e-04 - val_mae: 0.0245
# Epoch 482/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.1502e-04 - mae: 0.0230 - val_loss: 9.7485e-04 - val_mae: 0.0245
# Epoch 483/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1893e-04 - mae: 0.0232 - val_loss: 9.7342e-04 - val_mae: 0.0248
# Epoch 484/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2422e-04 - mae: 0.0231 - val_loss: 9.9007e-04 - val_mae: 0.0253
# Epoch 485/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2133e-04 - mae: 0.0231 - val_loss: 0.0010 - val_mae: 0.0261
# Epoch 486/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2769e-04 - mae: 0.0235 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 487/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2712e-04 - mae: 0.0232 - val_loss: 9.6100e-04 - val_mae: 0.0243
# Epoch 488/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.1175e-04 - mae: 0.0230 - val_loss: 9.4866e-04 - val_mae: 0.0238
# Epoch 489/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2331e-04 - mae: 0.0237 - val_loss: 9.6763e-04 - val_mae: 0.0245
# Epoch 490/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2995e-04 - mae: 0.0235 - val_loss: 9.5554e-04 - val_mae: 0.0242
# Epoch 491/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2856e-04 - mae: 0.0238 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 492/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.4616e-04 - mae: 0.0241 - val_loss: 9.5185e-04 - val_mae: 0.0240
# Epoch 493/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.2149e-04 - mae: 0.0233 - val_loss: 9.9681e-04 - val_mae: 0.0256
# Epoch 494/500
# 33/33 [==============================] - 1s 22ms/step - loss: 6.1285e-04 - mae: 0.0229 - val_loss: 9.5309e-04 - val_mae: 0.0242
# Epoch 495/500
# 33/33 [==============================] - 1s 24ms/step - loss: 6.2061e-04 - mae: 0.0232 - val_loss: 9.5414e-04 - val_mae: 0.0241
# Epoch 496/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.1642e-04 - mae: 0.0233 - val_loss: 0.0011 - val_mae: 0.0283
# Epoch 497/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.2407e-04 - mae: 0.0231 - val_loss: 9.5929e-04 - val_mae: 0.0243
# Epoch 498/500
# 33/33 [==============================] - 1s 23ms/step - loss: 6.1737e-04 - mae: 0.0229 - val_loss: 0.0011 - val_mae: 0.0281
# Epoch 499/500
# 33/33 [==============================] - 1s 30ms/step - loss: 6.3116e-04 - mae: 0.0235 - val_loss: 9.8440e-04 - val_mae: 0.0250
# Epoch 500/500
# 33/33 [==============================] - 1s 21ms/step - loss: 6.2835e-04 - mae: 0.0234 - val_loss: 0.0011 - val_mae: 0.0276

# %%
def get_val_mae(history=history):
    # Extract validation MAE history
    val_mae = history.history["val_mae"]
    
    # Find the index of the minimum val_mae
    best_epoch = np.argmin(val_mae) + 1  # +1 because epochs are 1-based
    best_val_mae = val_mae[best_epoch - 1]
    
    print(f"Best epoch: {best_epoch}, Best val_mae: {best_val_mae:.4f}")

# %%
# Extract validation MAE history
val_mae = history.history["val_mae"]

# Find the index of the minimum val_mae
best_epoch = np.argmin(val_mae) + 1  # +1 because epochs are 1-based
best_val_mae = val_mae[best_epoch - 1]

print(f"Best epoch: {best_epoch}, Best val_mae: {best_val_mae:.4f}")


get_val_mae(history=history)
# Out:
# Best epoch: 488, Best val_mae: 0.0238

# %%
# Last 56 values from your series
last_window = rail_series[-seq_length:].values  

# Reshape into (1, 56) because the model expects batch input
X_input = last_window.reshape(1, -1)

# Predict next day
next_day_pred = model.predict(X_input)[0][0]
print(f"Next day forecast: {next_day_pred:.2f}")
# Out:
# 1/1 [==============================] - 0s 283ms/step
# Next day forecast: 218240.92

# %%
def plot_history(history = history):
    # Extract history
    history_dict = history.history
    
    # Plot Loss
    plt.figure(figsize=(10,5))
    plt.plot(history_dict["loss"], label="Training Loss")
    plt.plot(history_dict["val_loss"], label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss (Huber)")
    plt.title("Training vs Validation Loss")
    plt.legend()
    plt.show()
    
    # Plot MAE
    plt.figure(figsize=(10,5))
    plt.plot(history_dict["mae"], label="Training MAE")
    plt.plot(history_dict["val_mae"], label="Validation MAE")
    plt.xlabel("Epochs")
    plt.ylabel("MAE")
    plt.title("Training vs Validation MAE")
    plt.legend()
    plt.show()

# %%
plot_history(history = history)

# %% [markdown]
# ---
# # Forecast Comparison
#
# |                          | Seasonal Naive Forecast | ARIMA        | Linear Model  |
# |--------------------------|------------------------|-------------|---------------|
# | **MAE**                  | 29,453.49             | 25,162.19   | 23,800        |
# | **Forecast (1st June 2025)** | 268,696           | 260,176.11  | 218,240.92    |
# | **Observed**             | 272,960               | 272,960     | 272,960       |
# | **Error %**              | 1.56%                 | 4.68%       | 20.05%        |
#
# - Looking at the **overall MAE**, the **Linear Model** performs best with the lowest MAE (23,800).
# - However, for the specific forecast of **June 1st, 2025**, the **Seasonal Naive Forecast** was closest to the observed value.
#
# ---

# %% [markdown]
# # Forecasting Using a Simple RNN

# %%
univar_model = tf.keras.Sequential([
 tf.keras.layers.SimpleRNN(32, input_shape=[None, 1]),
 tf.keras.layers.Dense(1)  # no activation function by default
 ])

early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor="val_mae", patience=50, restore_best_weights=True)
opt = tf.keras.optimizers.SGD(learning_rate=0.02, momentum=0.9)

univar_model.compile(loss=tf.keras.losses.Huber(), optimizer=opt, metrics=["mae"])
history = univar_model.fit(train_ds, validation_data=valid_ds, epochs=500, callbacks=[early_stopping_cb])
# Out:
# Epoch 1/500
# 33/33 [==============================] - 9s 186ms/step - loss: 0.0252 - mae: 0.1588 - val_loss: 0.0098 - val_mae: 0.1229
# Epoch 2/500
# 33/33 [==============================] - 6s 172ms/step - loss: 0.0056 - mae: 0.0869 - val_loss: 0.0043 - val_mae: 0.0772
# Epoch 3/500
# 33/33 [==============================] - 6s 177ms/step - loss: 0.0049 - mae: 0.0812 - val_loss: 0.0061 - val_mae: 0.0971
# Epoch 4/500
# 33/33 [==============================] - 5s 161ms/step - loss: 0.0044 - mae: 0.0765 - val_loss: 0.0062 - val_mae: 0.0986
# Epoch 5/500
# 33/33 [==============================] - 6s 164ms/step - loss: 0.0042 - mae: 0.0749 - val_loss: 0.0037 - val_mae: 0.0689
# Epoch 6/500
# 33/33 [==============================] - 5s 160ms/step - loss: 0.0042 - mae: 0.0741 - val_loss: 0.0075 - val_mae: 0.1095
# Epoch 7/500
# 33/33 [==============================] - 5s 160ms/step - loss: 0.0038 - mae: 0.0712 - val_loss: 0.0045 - val_mae: 0.0843
# Epoch 8/500
# 33/33 [==============================] - 5s 161ms/step - loss: 0.0039 - mae: 0.0713 - val_loss: 0.0034 - val_mae: 0.0615
# Epoch 9/500
# 33/33 [==============================] - 6s 170ms/step - loss: 0.0041 - mae: 0.0730 - val_loss: 0.0033 - val_mae: 0.0697
# Epoch 10/500
# 33/33 [==============================] - 6s 170ms/step - loss: 0.0034 - mae: 0.0671 - val_loss: 0.0033 - val_mae: 0.0714
# Epoch 11/500
# 33/33 [==============================] - 6s 182ms/step - loss: 0.0032 - mae: 0.0644 - val_loss: 0.0040 - val_mae: 0.0813
# Epoch 12/500
# 33/33 [==============================] - 6s 182ms/step - loss: 0.0030 - mae: 0.0626 - val_loss: 0.0032 - val_mae: 0.0713
# Epoch 13/500
# 33/33 [==============================] - 6s 184ms/step - loss: 0.0029 - mae: 0.0616 - val_loss: 0.0028 - val_mae: 0.0649
# Epoch 14/500
# 33/33 [==============================] - 6s 173ms/step - loss: 0.0030 - mae: 0.0622 - val_loss: 0.0030 - val_mae: 0.0690
# Epoch 15/500
# 33/33 [==============================] - 5s 163ms/step - loss: 0.0025 - mae: 0.0576 - val_loss: 0.0025 - val_mae: 0.0603
# Epoch 16/500
# 33/33 [==============================] - 5s 163ms/step - loss: 0.0025 - mae: 0.0572 - val_loss: 0.0024 - val_mae: 0.0587
# Epoch 17/500
# 33/33 [==============================] - 5s 162ms/step - loss: 0.0022 - mae: 0.0535 - val_loss: 0.0033 - val_mae: 0.0722
# Epoch 18/500
# 33/33 [==============================] - 5s 162ms/step - loss: 0.0020 - mae: 0.0513 - val_loss: 0.0021 - val_mae: 0.0532
# Epoch 19/500
# 33/33 [==============================] - 6s 165ms/step - loss: 0.0020 - mae: 0.0510 - val_loss: 0.0019 - val_mae: 0.0500
# Epoch 20/500
# 33/33 [==============================] - 6s 164ms/step - loss: 0.0017 - mae: 0.0461 - val_loss: 0.0030 - val_mae: 0.0666
# Epoch 21/500
# 33/33 [==============================] - 6s 166ms/step - loss: 0.0015 - mae: 0.0431 - val_loss: 0.0024 - val_mae: 0.0577
# Epoch 22/500
# 33/33 [==============================] - 6s 165ms/step - loss: 0.0015 - mae: 0.0420 - val_loss: 0.0017 - val_mae: 0.0443
# Epoch 23/500
# 33/33 [==============================] - 6s 163ms/step - loss: 0.0014 - mae: 0.0409 - val_loss: 0.0015 - val_mae: 0.0373
# Epoch 24/500
# 33/33 [==============================] - 6s 164ms/step - loss: 0.0015 - mae: 0.0416 - val_loss: 0.0015 - val_mae: 0.0374
# Epoch 25/500
# 33/33 [==============================] - 6s 171ms/step - loss: 0.0016 - mae: 0.0441 - val_loss: 0.0018 - val_mae: 0.0436
# Epoch 26/500
# 33/33 [==============================] - 6s 194ms/step - loss: 0.0014 - mae: 0.0405 - val_loss: 0.0014 - val_mae: 0.0368
# Epoch 27/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0013 - mae: 0.0390 - val_loss: 0.0016 - val_mae: 0.0399
# Epoch 28/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0013 - mae: 0.0387 - val_loss: 0.0017 - val_mae: 0.0424
# Epoch 29/500
# 33/33 [==============================] - 6s 176ms/step - loss: 0.0013 - mae: 0.0379 - val_loss: 0.0014 - val_mae: 0.0366
# Epoch 30/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0012 - mae: 0.0380 - val_loss: 0.0014 - val_mae: 0.0362
# Epoch 31/500
# 33/33 [==============================] - 6s 184ms/step - loss: 0.0012 - mae: 0.0368 - val_loss: 0.0017 - val_mae: 0.0414
# Epoch 32/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0012 - mae: 0.0368 - val_loss: 0.0014 - val_mae: 0.0378
# Epoch 33/500
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0014 - mae: 0.0398 - val_loss: 0.0018 - val_mae: 0.0438
# Epoch 34/500
# 33/33 [==============================] - 6s 183ms/step - loss: 0.0014 - mae: 0.0405 - val_loss: 0.0020 - val_mae: 0.0482
# Epoch 35/500
# 33/33 [==============================] - 7s 188ms/step - loss: 0.0011 - mae: 0.0358 - val_loss: 0.0014 - val_mae: 0.0365
# Epoch 36/500
# 33/33 [==============================] - 6s 192ms/step - loss: 0.0011 - mae: 0.0358 - val_loss: 0.0014 - val_mae: 0.0360
# Epoch 37/500
# 33/33 [==============================] - 7s 200ms/step - loss: 0.0012 - mae: 0.0374 - val_loss: 0.0016 - val_mae: 0.0411
# Epoch 38/500
# 33/33 [==============================] - 7s 194ms/step - loss: 0.0012 - mae: 0.0366 - val_loss: 0.0019 - val_mae: 0.0452
# Epoch 39/500
# 33/33 [==============================] - 6s 192ms/step - loss: 0.0012 - mae: 0.0359 - val_loss: 0.0014 - val_mae: 0.0353
# Epoch 40/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0012 - mae: 0.0362 - val_loss: 0.0014 - val_mae: 0.0351
# Epoch 41/500
# 33/33 [==============================] - 6s 183ms/step - loss: 0.0011 - mae: 0.0360 - val_loss: 0.0014 - val_mae: 0.0359
# Epoch 42/500
# 33/33 [==============================] - 6s 184ms/step - loss: 0.0011 - mae: 0.0358 - val_loss: 0.0015 - val_mae: 0.0377
# Epoch 43/500
# 33/33 [==============================] - 6s 179ms/step - loss: 0.0011 - mae: 0.0346 - val_loss: 0.0015 - val_mae: 0.0382
# Epoch 44/500
# 33/33 [==============================] - 6s 180ms/step - loss: 0.0012 - mae: 0.0362 - val_loss: 0.0018 - val_mae: 0.0446
# Epoch 45/500
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0011 - mae: 0.0343 - val_loss: 0.0014 - val_mae: 0.0347
# Epoch 46/500
# 33/33 [==============================] - 7s 199ms/step - loss: 0.0011 - mae: 0.0349 - val_loss: 0.0014 - val_mae: 0.0350
# Epoch 47/500
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0011 - mae: 0.0347 - val_loss: 0.0013 - val_mae: 0.0344
# Epoch 48/500
# 33/33 [==============================] - 6s 189ms/step - loss: 0.0011 - mae: 0.0340 - val_loss: 0.0015 - val_mae: 0.0389
# Epoch 49/500
# 33/33 [==============================] - 7s 196ms/step - loss: 0.0011 - mae: 0.0349 - val_loss: 0.0015 - val_mae: 0.0389
# Epoch 50/500
# 33/33 [==============================] - 6s 185ms/step - loss: 0.0010 - mae: 0.0330 - val_loss: 0.0014 - val_mae: 0.0367
# Epoch 51/500
# 33/33 [==============================] - 6s 192ms/step - loss: 9.9536e-04 - mae: 0.0330 - val_loss: 0.0014 - val_mae: 0.0365
# Epoch 52/500
# 33/33 [==============================] - 7s 201ms/step - loss: 0.0010 - mae: 0.0333 - val_loss: 0.0014 - val_mae: 0.0352
# Epoch 53/500
# 33/33 [==============================] - 6s 183ms/step - loss: 9.7679e-04 - mae: 0.0322 - val_loss: 0.0016 - val_mae: 0.0396
# Epoch 54/500
# 33/33 [==============================] - 6s 188ms/step - loss: 0.0010 - mae: 0.0328 - val_loss: 0.0015 - val_mae: 0.0373
# Epoch 55/500
# 33/33 [==============================] - 6s 180ms/step - loss: 0.0010 - mae: 0.0328 - val_loss: 0.0013 - val_mae: 0.0352
# Epoch 56/500
# 33/33 [==============================] - 6s 186ms/step - loss: 0.0011 - mae: 0.0339 - val_loss: 0.0018 - val_mae: 0.0437
# Epoch 57/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0010 - mae: 0.0330 - val_loss: 0.0019 - val_mae: 0.0468
# Epoch 58/500
# 33/33 [==============================] - 6s 182ms/step - loss: 0.0010 - mae: 0.0338 - val_loss: 0.0014 - val_mae: 0.0343
# Epoch 59/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0010 - mae: 0.0332 - val_loss: 0.0018 - val_mae: 0.0442
# Epoch 60/500
# 33/33 [==============================] - 6s 177ms/step - loss: 0.0011 - mae: 0.0345 - val_loss: 0.0014 - val_mae: 0.0360
# Epoch 61/500
# 33/33 [==============================] - 6s 194ms/step - loss: 9.4201e-04 - mae: 0.0314 - val_loss: 0.0013 - val_mae: 0.0326
# Epoch 62/500
# 33/33 [==============================] - 6s 183ms/step - loss: 9.8479e-04 - mae: 0.0326 - val_loss: 0.0013 - val_mae: 0.0332
# Epoch 63/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0010 - mae: 0.0331 - val_loss: 0.0014 - val_mae: 0.0352
# Epoch 64/500
# 33/33 [==============================] - 6s 177ms/step - loss: 9.6269e-04 - mae: 0.0319 - val_loss: 0.0013 - val_mae: 0.0320
# Epoch 65/500
# 33/33 [==============================] - 6s 175ms/step - loss: 9.3608e-04 - mae: 0.0310 - val_loss: 0.0017 - val_mae: 0.0441
# Epoch 66/500
# 33/33 [==============================] - 6s 171ms/step - loss: 0.0010 - mae: 0.0334 - val_loss: 0.0015 - val_mae: 0.0381
# Epoch 67/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0010 - mae: 0.0334 - val_loss: 0.0014 - val_mae: 0.0357
# Epoch 68/500
# 33/33 [==============================] - 6s 168ms/step - loss: 9.0131e-04 - mae: 0.0303 - val_loss: 0.0013 - val_mae: 0.0322
# Epoch 69/500
# 33/33 [==============================] - 6s 166ms/step - loss: 0.0010 - mae: 0.0331 - val_loss: 0.0018 - val_mae: 0.0436
# Epoch 70/500
# 33/33 [==============================] - 6s 172ms/step - loss: 9.5987e-04 - mae: 0.0319 - val_loss: 0.0015 - val_mae: 0.0397
# Epoch 71/500
# 33/33 [==============================] - 6s 172ms/step - loss: 9.4764e-04 - mae: 0.0320 - val_loss: 0.0014 - val_mae: 0.0347
# Epoch 72/500
# 33/33 [==============================] - 6s 171ms/step - loss: 9.2589e-04 - mae: 0.0311 - val_loss: 0.0012 - val_mae: 0.0307
# Epoch 73/500
# 33/33 [==============================] - 6s 172ms/step - loss: 9.1889e-04 - mae: 0.0307 - val_loss: 0.0013 - val_mae: 0.0332
# Epoch 74/500
# 33/33 [==============================] - 6s 175ms/step - loss: 9.7805e-04 - mae: 0.0315 - val_loss: 0.0017 - val_mae: 0.0444
# Epoch 75/500
# 33/33 [==============================] - 6s 169ms/step - loss: 9.5185e-04 - mae: 0.0319 - val_loss: 0.0015 - val_mae: 0.0377
# Epoch 76/500
# 33/33 [==============================] - 6s 168ms/step - loss: 8.7432e-04 - mae: 0.0298 - val_loss: 0.0012 - val_mae: 0.0306
# Epoch 77/500
# 33/33 [==============================] - 6s 184ms/step - loss: 9.1240e-04 - mae: 0.0304 - val_loss: 0.0014 - val_mae: 0.0358
# Epoch 78/500
# 33/33 [==============================] - 6s 185ms/step - loss: 0.0010 - mae: 0.0326 - val_loss: 0.0014 - val_mae: 0.0367
# Epoch 79/500
# 33/33 [==============================] - 6s 176ms/step - loss: 0.0010 - mae: 0.0327 - val_loss: 0.0015 - val_mae: 0.0395
# Epoch 80/500
# 33/33 [==============================] - 6s 173ms/step - loss: 0.0010 - mae: 0.0337 - val_loss: 0.0012 - val_mae: 0.0300
# Epoch 81/500
# 33/33 [==============================] - 6s 177ms/step - loss: 8.6541e-04 - mae: 0.0291 - val_loss: 0.0011 - val_mae: 0.0297
# Epoch 82/500
# 33/33 [==============================] - 6s 173ms/step - loss: 9.2436e-04 - mae: 0.0310 - val_loss: 0.0012 - val_mae: 0.0294
# Epoch 83/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.6271e-04 - mae: 0.0294 - val_loss: 0.0012 - val_mae: 0.0298
# Epoch 84/500
# 33/33 [==============================] - 6s 184ms/step - loss: 8.8907e-04 - mae: 0.0304 - val_loss: 0.0013 - val_mae: 0.0350
# Epoch 85/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.8485e-04 - mae: 0.0298 - val_loss: 0.0012 - val_mae: 0.0302
# Epoch 86/500
# 33/33 [==============================] - 6s 175ms/step - loss: 8.4519e-04 - mae: 0.0290 - val_loss: 0.0012 - val_mae: 0.0305
# Epoch 87/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.5052e-04 - mae: 0.0293 - val_loss: 0.0012 - val_mae: 0.0293
# Epoch 88/500
# 33/33 [==============================] - 6s 192ms/step - loss: 8.2752e-04 - mae: 0.0284 - val_loss: 0.0011 - val_mae: 0.0298
# Epoch 89/500
# 33/33 [==============================] - 6s 193ms/step - loss: 8.8000e-04 - mae: 0.0297 - val_loss: 0.0012 - val_mae: 0.0318
# Epoch 90/500
# 33/33 [==============================] - 6s 176ms/step - loss: 8.3375e-04 - mae: 0.0287 - val_loss: 0.0013 - val_mae: 0.0324
# Epoch 91/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.2596e-04 - mae: 0.0286 - val_loss: 0.0011 - val_mae: 0.0289
# Epoch 92/500
# 33/33 [==============================] - 6s 175ms/step - loss: 8.8608e-04 - mae: 0.0298 - val_loss: 0.0011 - val_mae: 0.0291
# Epoch 93/500
# 33/33 [==============================] - 6s 164ms/step - loss: 9.2425e-04 - mae: 0.0307 - val_loss: 0.0012 - val_mae: 0.0325
# Epoch 94/500
# 33/33 [==============================] - 6s 171ms/step - loss: 9.7690e-04 - mae: 0.0319 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 95/500
# 33/33 [==============================] - 6s 178ms/step - loss: 8.5832e-04 - mae: 0.0292 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 96/500
# 33/33 [==============================] - 6s 176ms/step - loss: 8.4337e-04 - mae: 0.0288 - val_loss: 0.0011 - val_mae: 0.0289
# Epoch 97/500
# 33/33 [==============================] - 6s 176ms/step - loss: 9.0337e-04 - mae: 0.0307 - val_loss: 0.0016 - val_mae: 0.0403
# Epoch 98/500
# 33/33 [==============================] - 6s 174ms/step - loss: 9.0061e-04 - mae: 0.0304 - val_loss: 0.0014 - val_mae: 0.0379
# Epoch 99/500
# 33/33 [==============================] - 6s 175ms/step - loss: 8.6984e-04 - mae: 0.0293 - val_loss: 0.0012 - val_mae: 0.0324
# Epoch 100/500
# 33/33 [==============================] - 6s 176ms/step - loss: 8.2506e-04 - mae: 0.0282 - val_loss: 0.0012 - val_mae: 0.0321
# Epoch 101/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.6737e-04 - mae: 0.0293 - val_loss: 0.0011 - val_mae: 0.0297
# Epoch 102/500
# 33/33 [==============================] - 6s 176ms/step - loss: 8.7695e-04 - mae: 0.0296 - val_loss: 0.0012 - val_mae: 0.0326
# Epoch 103/500
# 33/33 [==============================] - 6s 181ms/step - loss: 7.7680e-04 - mae: 0.0275 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 104/500
# 33/33 [==============================] - 6s 179ms/step - loss: 7.9056e-04 - mae: 0.0273 - val_loss: 0.0011 - val_mae: 0.0304
# Epoch 105/500
# 33/33 [==============================] - 6s 190ms/step - loss: 8.3440e-04 - mae: 0.0287 - val_loss: 0.0011 - val_mae: 0.0314
# Epoch 106/500
# 33/33 [==============================] - 6s 181ms/step - loss: 9.2327e-04 - mae: 0.0308 - val_loss: 0.0011 - val_mae: 0.0279
# Epoch 107/500
# 33/33 [==============================] - 6s 175ms/step - loss: 8.3254e-04 - mae: 0.0291 - val_loss: 0.0011 - val_mae: 0.0291
# Epoch 108/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.5705e-04 - mae: 0.0294 - val_loss: 0.0012 - val_mae: 0.0328
# Epoch 109/500
# 33/33 [==============================] - 6s 173ms/step - loss: 8.9343e-04 - mae: 0.0300 - val_loss: 0.0011 - val_mae: 0.0287
# Epoch 110/500
# 33/33 [==============================] - 6s 174ms/step - loss: 8.3607e-04 - mae: 0.0287 - val_loss: 0.0011 - val_mae: 0.0286
# Epoch 111/500
# 33/33 [==============================] - 6s 181ms/step - loss: 8.3626e-04 - mae: 0.0287 - val_loss: 0.0011 - val_mae: 0.0280
# Epoch 112/500
# 33/33 [==============================] - 6s 177ms/step - loss: 9.1266e-04 - mae: 0.0306 - val_loss: 0.0017 - val_mae: 0.0448
# Epoch 113/500
# 33/33 [==============================] - 6s 175ms/step - loss: 8.3761e-04 - mae: 0.0286 - val_loss: 0.0010 - val_mae: 0.0279
# Epoch 114/500
# 33/33 [==============================] - 6s 184ms/step - loss: 7.7319e-04 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0312
# Epoch 115/500
# 33/33 [==============================] - 6s 185ms/step - loss: 7.8695e-04 - mae: 0.0274 - val_loss: 0.0013 - val_mae: 0.0339
# Epoch 116/500
# 33/33 [==============================] - 6s 182ms/step - loss: 8.7579e-04 - mae: 0.0297 - val_loss: 0.0011 - val_mae: 0.0279
# Epoch 117/500
# 33/33 [==============================] - 6s 179ms/step - loss: 7.7257e-04 - mae: 0.0270 - val_loss: 0.0011 - val_mae: 0.0281
# Epoch 118/500
# 33/33 [==============================] - 6s 183ms/step - loss: 8.3819e-04 - mae: 0.0287 - val_loss: 0.0011 - val_mae: 0.0284
# Epoch 119/500
# 33/33 [==============================] - 6s 179ms/step - loss: 7.6894e-04 - mae: 0.0272 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 120/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.6832e-04 - mae: 0.0267 - val_loss: 0.0010 - val_mae: 0.0272
# Epoch 121/500
# 33/33 [==============================] - 6s 182ms/step - loss: 7.7629e-04 - mae: 0.0269 - val_loss: 0.0014 - val_mae: 0.0367
# Epoch 122/500
# 33/33 [==============================] - 6s 178ms/step - loss: 8.4962e-04 - mae: 0.0289 - val_loss: 0.0010 - val_mae: 0.0280
# Epoch 123/500
# 33/33 [==============================] - 6s 176ms/step - loss: 7.9377e-04 - mae: 0.0273 - val_loss: 0.0014 - val_mae: 0.0370
# Epoch 124/500
# 33/33 [==============================] - 6s 178ms/step - loss: 8.0349e-04 - mae: 0.0280 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 125/500
# 33/33 [==============================] - 6s 184ms/step - loss: 8.1659e-04 - mae: 0.0284 - val_loss: 0.0011 - val_mae: 0.0290
# Epoch 126/500
# 33/33 [==============================] - 6s 173ms/step - loss: 7.9700e-04 - mae: 0.0276 - val_loss: 0.0012 - val_mae: 0.0304
# Epoch 127/500
# 33/33 [==============================] - 6s 171ms/step - loss: 7.5039e-04 - mae: 0.0267 - val_loss: 0.0011 - val_mae: 0.0274
# Epoch 128/500
# 33/33 [==============================] - 6s 173ms/step - loss: 7.3918e-04 - mae: 0.0260 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 129/500
# 33/33 [==============================] - 6s 171ms/step - loss: 7.4322e-04 - mae: 0.0261 - val_loss: 0.0010 - val_mae: 0.0267
# Epoch 130/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.4889e-04 - mae: 0.0264 - val_loss: 0.0010 - val_mae: 0.0264
# Epoch 131/500
# 33/33 [==============================] - 6s 181ms/step - loss: 7.4613e-04 - mae: 0.0263 - val_loss: 9.9791e-04 - val_mae: 0.0268
# Epoch 132/500
# 33/33 [==============================] - 6s 185ms/step - loss: 7.9021e-04 - mae: 0.0273 - val_loss: 0.0011 - val_mae: 0.0291
# Epoch 133/500
# 33/33 [==============================] - 6s 189ms/step - loss: 7.5061e-04 - mae: 0.0263 - val_loss: 0.0010 - val_mae: 0.0274
# Epoch 134/500
# 33/33 [==============================] - 6s 189ms/step - loss: 7.3014e-04 - mae: 0.0261 - val_loss: 0.0011 - val_mae: 0.0277
# Epoch 135/500
# 33/33 [==============================] - 7s 193ms/step - loss: 7.8507e-04 - mae: 0.0272 - val_loss: 0.0012 - val_mae: 0.0310
# Epoch 136/500
# 33/33 [==============================] - 6s 181ms/step - loss: 7.4001e-04 - mae: 0.0261 - val_loss: 0.0010 - val_mae: 0.0283
# Epoch 137/500
# 33/33 [==============================] - 6s 179ms/step - loss: 8.4208e-04 - mae: 0.0286 - val_loss: 0.0010 - val_mae: 0.0273
# Epoch 138/500
# 33/33 [==============================] - 6s 181ms/step - loss: 7.3115e-04 - mae: 0.0259 - val_loss: 0.0011 - val_mae: 0.0308
# Epoch 139/500
# 33/33 [==============================] - 6s 187ms/step - loss: 7.5420e-04 - mae: 0.0267 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 140/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.9255e-04 - mae: 0.0273 - val_loss: 0.0012 - val_mae: 0.0311
# Epoch 141/500
# 33/33 [==============================] - 6s 186ms/step - loss: 8.1206e-04 - mae: 0.0280 - val_loss: 0.0010 - val_mae: 0.0268
# Epoch 142/500
# 33/33 [==============================] - 6s 190ms/step - loss: 7.4788e-04 - mae: 0.0264 - val_loss: 0.0010 - val_mae: 0.0269
# Epoch 143/500
# 33/33 [==============================] - 7s 197ms/step - loss: 7.6104e-04 - mae: 0.0265 - val_loss: 0.0010 - val_mae: 0.0276
# Epoch 144/500
# 33/33 [==============================] - 6s 190ms/step - loss: 7.5183e-04 - mae: 0.0271 - val_loss: 0.0013 - val_mae: 0.0347
# Epoch 145/500
# 33/33 [==============================] - 6s 178ms/step - loss: 7.7380e-04 - mae: 0.0272 - val_loss: 0.0011 - val_mae: 0.0285
# Epoch 146/500
# 33/33 [==============================] - 6s 168ms/step - loss: 7.7219e-04 - mae: 0.0267 - val_loss: 9.8739e-04 - val_mae: 0.0270
# Epoch 147/500
# 33/33 [==============================] - 6s 169ms/step - loss: 7.5021e-04 - mae: 0.0265 - val_loss: 0.0011 - val_mae: 0.0285
# Epoch 148/500
# 33/33 [==============================] - 6s 173ms/step - loss: 7.3028e-04 - mae: 0.0260 - val_loss: 9.9657e-04 - val_mae: 0.0260
# Epoch 149/500
# 33/33 [==============================] - 6s 169ms/step - loss: 7.2825e-04 - mae: 0.0258 - val_loss: 0.0011 - val_mae: 0.0295
# Epoch 150/500
# 33/33 [==============================] - 6s 169ms/step - loss: 7.9606e-04 - mae: 0.0282 - val_loss: 0.0013 - val_mae: 0.0355
# Epoch 151/500
# 33/33 [==============================] - 6s 176ms/step - loss: 7.4015e-04 - mae: 0.0261 - val_loss: 0.0010 - val_mae: 0.0271
# Epoch 152/500
# 33/33 [==============================] - 6s 178ms/step - loss: 7.1478e-04 - mae: 0.0255 - val_loss: 9.5204e-04 - val_mae: 0.0259
# Epoch 153/500
# 33/33 [==============================] - 6s 174ms/step - loss: 7.7588e-04 - mae: 0.0265 - val_loss: 9.9943e-04 - val_mae: 0.0273
# Epoch 154/500
# 33/33 [==============================] - 6s 180ms/step - loss: 7.1369e-04 - mae: 0.0253 - val_loss: 9.4138e-04 - val_mae: 0.0255
# Epoch 155/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.2104e-04 - mae: 0.0259 - val_loss: 9.4056e-04 - val_mae: 0.0249
# Epoch 156/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.3232e-04 - mae: 0.0255 - val_loss: 9.4892e-04 - val_mae: 0.0262
# Epoch 157/500
# 33/33 [==============================] - 6s 171ms/step - loss: 7.9179e-04 - mae: 0.0273 - val_loss: 9.3626e-04 - val_mae: 0.0255
# Epoch 158/500
# 33/33 [==============================] - 6s 174ms/step - loss: 7.5899e-04 - mae: 0.0265 - val_loss: 0.0011 - val_mae: 0.0292
# Epoch 159/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.4485e-04 - mae: 0.0263 - val_loss: 9.2676e-04 - val_mae: 0.0250
# Epoch 160/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.9889e-04 - mae: 0.0250 - val_loss: 9.4996e-04 - val_mae: 0.0258
# Epoch 161/500
# 33/33 [==============================] - 6s 169ms/step - loss: 7.1649e-04 - mae: 0.0254 - val_loss: 0.0011 - val_mae: 0.0299
# Epoch 162/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.7225e-04 - mae: 0.0271 - val_loss: 9.2068e-04 - val_mae: 0.0247
# Epoch 163/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.3569e-04 - mae: 0.0262 - val_loss: 9.1865e-04 - val_mae: 0.0251
# Epoch 164/500
# 33/33 [==============================] - 6s 173ms/step - loss: 7.1944e-04 - mae: 0.0258 - val_loss: 0.0013 - val_mae: 0.0349
# Epoch 165/500
# 33/33 [==============================] - 6s 167ms/step - loss: 7.4164e-04 - mae: 0.0262 - val_loss: 9.2584e-04 - val_mae: 0.0252
# Epoch 166/500
# 33/33 [==============================] - 6s 174ms/step - loss: 7.0400e-04 - mae: 0.0253 - val_loss: 9.2618e-04 - val_mae: 0.0251
# Epoch 167/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.9543e-04 - mae: 0.0247 - val_loss: 9.4431e-04 - val_mae: 0.0269
# Epoch 168/500
# 33/33 [==============================] - 6s 171ms/step - loss: 7.1084e-04 - mae: 0.0257 - val_loss: 9.1043e-04 - val_mae: 0.0253
# Epoch 169/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.9051e-04 - mae: 0.0247 - val_loss: 9.6482e-04 - val_mae: 0.0267
# Epoch 170/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.9997e-04 - mae: 0.0248 - val_loss: 0.0011 - val_mae: 0.0306
# Epoch 171/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.2864e-04 - mae: 0.0258 - val_loss: 9.2528e-04 - val_mae: 0.0258
# Epoch 172/500
# 33/33 [==============================] - 6s 184ms/step - loss: 7.1772e-04 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0280
# Epoch 173/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.9165e-04 - mae: 0.0245 - val_loss: 9.7921e-04 - val_mae: 0.0270
# Epoch 174/500
# 33/33 [==============================] - 6s 182ms/step - loss: 6.7928e-04 - mae: 0.0245 - val_loss: 0.0010 - val_mae: 0.0286
# Epoch 175/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.9150e-04 - mae: 0.0248 - val_loss: 8.8924e-04 - val_mae: 0.0250
# Epoch 176/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.8710e-04 - mae: 0.0251 - val_loss: 8.7085e-04 - val_mae: 0.0238
# Epoch 177/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.2494e-04 - mae: 0.0256 - val_loss: 0.0011 - val_mae: 0.0317
# Epoch 178/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.9920e-04 - mae: 0.0245 - val_loss: 8.6479e-04 - val_mae: 0.0240
# Epoch 179/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.3031e-04 - mae: 0.0267 - val_loss: 8.8014e-04 - val_mae: 0.0244
# Epoch 180/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.7618e-04 - mae: 0.0243 - val_loss: 0.0010 - val_mae: 0.0286
# Epoch 181/500
# 33/33 [==============================] - 6s 186ms/step - loss: 7.1179e-04 - mae: 0.0256 - val_loss: 9.1384e-04 - val_mae: 0.0260
# Epoch 182/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.6922e-04 - mae: 0.0241 - val_loss: 8.7091e-04 - val_mae: 0.0244
# Epoch 183/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.8411e-04 - mae: 0.0244 - val_loss: 8.4456e-04 - val_mae: 0.0241
# Epoch 184/500
# 33/33 [==============================] - 6s 184ms/step - loss: 7.0445e-04 - mae: 0.0253 - val_loss: 8.4185e-04 - val_mae: 0.0229
# Epoch 185/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.6801e-04 - mae: 0.0239 - val_loss: 8.3393e-04 - val_mae: 0.0235
# Epoch 186/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.8967e-04 - mae: 0.0244 - val_loss: 8.3470e-04 - val_mae: 0.0245
# Epoch 187/500
# 33/33 [==============================] - 6s 181ms/step - loss: 7.0946e-04 - mae: 0.0254 - val_loss: 8.5338e-04 - val_mae: 0.0242
# Epoch 188/500
# 33/33 [==============================] - 6s 178ms/step - loss: 7.3717e-04 - mae: 0.0258 - val_loss: 8.4574e-04 - val_mae: 0.0240
# Epoch 189/500
# 33/33 [==============================] - 6s 175ms/step - loss: 7.0021e-04 - mae: 0.0256 - val_loss: 9.1654e-04 - val_mae: 0.0273
# Epoch 190/500
# 33/33 [==============================] - 6s 194ms/step - loss: 7.2618e-04 - mae: 0.0257 - val_loss: 8.8939e-04 - val_mae: 0.0254
# Epoch 191/500
# 33/33 [==============================] - 6s 184ms/step - loss: 6.8677e-04 - mae: 0.0244 - val_loss: 0.0011 - val_mae: 0.0320
# Epoch 192/500
# 33/33 [==============================] - 6s 182ms/step - loss: 6.8626e-04 - mae: 0.0246 - val_loss: 8.9537e-04 - val_mae: 0.0257
# Epoch 193/500
# 33/33 [==============================] - 6s 176ms/step - loss: 7.5036e-04 - mae: 0.0267 - val_loss: 9.2405e-04 - val_mae: 0.0267
# Epoch 194/500
# 33/33 [==============================] - 6s 183ms/step - loss: 7.2183e-04 - mae: 0.0257 - val_loss: 8.6537e-04 - val_mae: 0.0240
# Epoch 195/500
# 33/33 [==============================] - 6s 185ms/step - loss: 6.9229e-04 - mae: 0.0247 - val_loss: 8.6757e-04 - val_mae: 0.0252
# Epoch 196/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.8540e-04 - mae: 0.0245 - val_loss: 9.0639e-04 - val_mae: 0.0262
# Epoch 197/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.6031e-04 - mae: 0.0238 - val_loss: 7.8865e-04 - val_mae: 0.0227
# Epoch 198/500
# 33/33 [==============================] - 6s 174ms/step - loss: 7.1706e-04 - mae: 0.0259 - val_loss: 8.0224e-04 - val_mae: 0.0233
# Epoch 199/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.6233e-04 - mae: 0.0237 - val_loss: 8.0575e-04 - val_mae: 0.0248
# Epoch 200/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.7842e-04 - mae: 0.0246 - val_loss: 8.0465e-04 - val_mae: 0.0246
# Epoch 201/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.8377e-04 - mae: 0.0246 - val_loss: 8.8283e-04 - val_mae: 0.0254
# Epoch 202/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.9755e-04 - mae: 0.0249 - val_loss: 8.4067e-04 - val_mae: 0.0242
# Epoch 203/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.4469e-04 - mae: 0.0234 - val_loss: 7.8572e-04 - val_mae: 0.0223
# Epoch 204/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.5645e-04 - mae: 0.0236 - val_loss: 8.5171e-04 - val_mae: 0.0245
# Epoch 205/500
# 33/33 [==============================] - 6s 169ms/step - loss: 6.5577e-04 - mae: 0.0237 - val_loss: 8.3677e-04 - val_mae: 0.0248
# Epoch 206/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.5951e-04 - mae: 0.0236 - val_loss: 7.9045e-04 - val_mae: 0.0218
# Epoch 207/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.7709e-04 - mae: 0.0244 - val_loss: 8.0130e-04 - val_mae: 0.0242
# Epoch 208/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.5690e-04 - mae: 0.0240 - val_loss: 7.8146e-04 - val_mae: 0.0220
# Epoch 209/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.4825e-04 - mae: 0.0233 - val_loss: 8.2092e-04 - val_mae: 0.0230
# Epoch 210/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.5878e-04 - mae: 0.0235 - val_loss: 7.8622e-04 - val_mae: 0.0225
# Epoch 211/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.4924e-04 - mae: 0.0231 - val_loss: 8.2497e-04 - val_mae: 0.0245
# Epoch 212/500
# 33/33 [==============================] - 6s 170ms/step - loss: 6.9107e-04 - mae: 0.0247 - val_loss: 8.7564e-04 - val_mae: 0.0259
# Epoch 213/500
# 33/33 [==============================] - 6s 173ms/step - loss: 7.4315e-04 - mae: 0.0263 - val_loss: 0.0010 - val_mae: 0.0294
# Epoch 214/500
# 33/33 [==============================] - 6s 175ms/step - loss: 7.8241e-04 - mae: 0.0273 - val_loss: 9.6567e-04 - val_mae: 0.0279
# Epoch 215/500
# 33/33 [==============================] - 6s 171ms/step - loss: 6.9899e-04 - mae: 0.0250 - val_loss: 7.8309e-04 - val_mae: 0.0226
# Epoch 216/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.9437e-04 - mae: 0.0245 - val_loss: 7.8321e-04 - val_mae: 0.0231
# Epoch 217/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.9770e-04 - mae: 0.0254 - val_loss: 8.0029e-04 - val_mae: 0.0237
# Epoch 218/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.0935e-04 - mae: 0.0257 - val_loss: 7.8597e-04 - val_mae: 0.0230
# Epoch 219/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.7177e-04 - mae: 0.0239 - val_loss: 8.3849e-04 - val_mae: 0.0237
# Epoch 220/500
# 33/33 [==============================] - 6s 165ms/step - loss: 6.6163e-04 - mae: 0.0235 - val_loss: 8.3294e-04 - val_mae: 0.0232
# Epoch 221/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.6556e-04 - mae: 0.0239 - val_loss: 7.8453e-04 - val_mae: 0.0223
# Epoch 222/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.7804e-04 - mae: 0.0242 - val_loss: 8.1906e-04 - val_mae: 0.0235
# Epoch 223/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.7121e-04 - mae: 0.0243 - val_loss: 7.8847e-04 - val_mae: 0.0221
# Epoch 224/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.7397e-04 - mae: 0.0240 - val_loss: 7.7691e-04 - val_mae: 0.0229
# Epoch 225/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.8869e-04 - mae: 0.0247 - val_loss: 7.8546e-04 - val_mae: 0.0220
# Epoch 226/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.7240e-04 - mae: 0.0238 - val_loss: 8.1453e-04 - val_mae: 0.0229
# Epoch 227/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.9516e-04 - mae: 0.0246 - val_loss: 9.4328e-04 - val_mae: 0.0272
# Epoch 228/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.6276e-04 - mae: 0.0239 - val_loss: 0.0010 - val_mae: 0.0297
# Epoch 229/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.6318e-04 - mae: 0.0240 - val_loss: 7.9847e-04 - val_mae: 0.0235
# Epoch 230/500
# 33/33 [==============================] - 6s 173ms/step - loss: 7.0645e-04 - mae: 0.0250 - val_loss: 8.4190e-04 - val_mae: 0.0244
# Epoch 231/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.7157e-04 - mae: 0.0239 - val_loss: 8.1013e-04 - val_mae: 0.0230
# Epoch 232/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.7279e-04 - mae: 0.0239 - val_loss: 8.7190e-04 - val_mae: 0.0248
# Epoch 233/500
# 33/33 [==============================] - 6s 169ms/step - loss: 6.5871e-04 - mae: 0.0239 - val_loss: 8.6654e-04 - val_mae: 0.0249
# Epoch 234/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.3830e-04 - mae: 0.0228 - val_loss: 8.9562e-04 - val_mae: 0.0257
# Epoch 235/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.7950e-04 - mae: 0.0242 - val_loss: 8.2114e-04 - val_mae: 0.0253
# Epoch 236/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.9376e-04 - mae: 0.0245 - val_loss: 7.9804e-04 - val_mae: 0.0241
# Epoch 237/500
# 33/33 [==============================] - 6s 169ms/step - loss: 6.5973e-04 - mae: 0.0237 - val_loss: 7.7650e-04 - val_mae: 0.0218
# Epoch 238/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.7484e-04 - mae: 0.0240 - val_loss: 0.0011 - val_mae: 0.0327
# Epoch 239/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.6176e-04 - mae: 0.0238 - val_loss: 7.8668e-04 - val_mae: 0.0239
# Epoch 240/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.7730e-04 - mae: 0.0241 - val_loss: 7.8475e-04 - val_mae: 0.0228
# Epoch 241/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.3876e-04 - mae: 0.0231 - val_loss: 9.0135e-04 - val_mae: 0.0259
# Epoch 242/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.6251e-04 - mae: 0.0238 - val_loss: 7.8455e-04 - val_mae: 0.0219
# Epoch 243/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.3488e-04 - mae: 0.0230 - val_loss: 7.7632e-04 - val_mae: 0.0222
# Epoch 244/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.5742e-04 - mae: 0.0237 - val_loss: 9.9090e-04 - val_mae: 0.0287
# Epoch 245/500
# 33/33 [==============================] - 6s 189ms/step - loss: 6.6884e-04 - mae: 0.0237 - val_loss: 7.8622e-04 - val_mae: 0.0226
# Epoch 246/500
# 33/33 [==============================] - 6s 192ms/step - loss: 6.8788e-04 - mae: 0.0244 - val_loss: 7.7831e-04 - val_mae: 0.0236
# Epoch 247/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.5033e-04 - mae: 0.0238 - val_loss: 8.4079e-04 - val_mae: 0.0240
# Epoch 248/500
# 33/33 [==============================] - 6s 184ms/step - loss: 6.4576e-04 - mae: 0.0230 - val_loss: 7.7209e-04 - val_mae: 0.0216
# Epoch 249/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.4236e-04 - mae: 0.0231 - val_loss: 0.0011 - val_mae: 0.0310
# Epoch 250/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.6628e-04 - mae: 0.0239 - val_loss: 7.8038e-04 - val_mae: 0.0227
# Epoch 251/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.6525e-04 - mae: 0.0237 - val_loss: 8.0028e-04 - val_mae: 0.0222
# Epoch 252/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.6792e-04 - mae: 0.0244 - val_loss: 8.2143e-04 - val_mae: 0.0238
# Epoch 253/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.5752e-04 - mae: 0.0236 - val_loss: 9.1197e-04 - val_mae: 0.0261
# Epoch 254/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.5346e-04 - mae: 0.0241 - val_loss: 8.4862e-04 - val_mae: 0.0243
# Epoch 255/500
# 33/33 [==============================] - 6s 182ms/step - loss: 6.7955e-04 - mae: 0.0251 - val_loss: 7.8491e-04 - val_mae: 0.0236
# Epoch 256/500
# 33/33 [==============================] - 6s 170ms/step - loss: 6.7987e-04 - mae: 0.0240 - val_loss: 8.1317e-04 - val_mae: 0.0233
# Epoch 257/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.4468e-04 - mae: 0.0230 - val_loss: 7.7484e-04 - val_mae: 0.0226
# Epoch 258/500
# 33/33 [==============================] - 6s 184ms/step - loss: 6.4166e-04 - mae: 0.0230 - val_loss: 8.7351e-04 - val_mae: 0.0252
# Epoch 259/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.4704e-04 - mae: 0.0233 - val_loss: 8.0681e-04 - val_mae: 0.0236
# Epoch 260/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.8086e-04 - mae: 0.0243 - val_loss: 7.8876e-04 - val_mae: 0.0241
# Epoch 261/500
# 33/33 [==============================] - 6s 172ms/step - loss: 7.2252e-04 - mae: 0.0251 - val_loss: 0.0011 - val_mae: 0.0331
# Epoch 262/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.6928e-04 - mae: 0.0243 - val_loss: 8.7425e-04 - val_mae: 0.0251
# Epoch 263/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.4990e-04 - mae: 0.0235 - val_loss: 7.9576e-04 - val_mae: 0.0219
# Epoch 264/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.8012e-04 - mae: 0.0245 - val_loss: 8.5840e-04 - val_mae: 0.0257
# Epoch 265/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.6259e-04 - mae: 0.0234 - val_loss: 7.6147e-04 - val_mae: 0.0223
# Epoch 266/500
# 33/33 [==============================] - 6s 171ms/step - loss: 6.3634e-04 - mae: 0.0232 - val_loss: 8.4002e-04 - val_mae: 0.0236
# Epoch 267/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.3507e-04 - mae: 0.0227 - val_loss: 8.2013e-04 - val_mae: 0.0243
# Epoch 268/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.9592e-04 - mae: 0.0252 - val_loss: 7.6475e-04 - val_mae: 0.0227
# Epoch 269/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.5087e-04 - mae: 0.0232 - val_loss: 7.6379e-04 - val_mae: 0.0218
# Epoch 270/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.5238e-04 - mae: 0.0232 - val_loss: 8.8280e-04 - val_mae: 0.0253
# Epoch 271/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.5820e-04 - mae: 0.0237 - val_loss: 0.0011 - val_mae: 0.0319
# Epoch 272/500
# 33/33 [==============================] - 6s 176ms/step - loss: 8.2560e-04 - mae: 0.0284 - val_loss: 8.6642e-04 - val_mae: 0.0270
# Epoch 273/500
# 33/33 [==============================] - 6s 168ms/step - loss: 6.7487e-04 - mae: 0.0242 - val_loss: 7.9028e-04 - val_mae: 0.0222
# Epoch 274/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.6004e-04 - mae: 0.0238 - val_loss: 9.5542e-04 - val_mae: 0.0277
# Epoch 275/500
# 33/33 [==============================] - 6s 186ms/step - loss: 6.8998e-04 - mae: 0.0248 - val_loss: 7.9055e-04 - val_mae: 0.0215
# Epoch 276/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.5072e-04 - mae: 0.0231 - val_loss: 9.6596e-04 - val_mae: 0.0281
# Epoch 277/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.8912e-04 - mae: 0.0243 - val_loss: 0.0011 - val_mae: 0.0336
# Epoch 278/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.6128e-04 - mae: 0.0242 - val_loss: 7.7076e-04 - val_mae: 0.0217
# Epoch 279/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.4158e-04 - mae: 0.0230 - val_loss: 7.6946e-04 - val_mae: 0.0228
# Epoch 280/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.4387e-04 - mae: 0.0227 - val_loss: 7.7206e-04 - val_mae: 0.0227
# Epoch 281/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.5028e-04 - mae: 0.0234 - val_loss: 7.7671e-04 - val_mae: 0.0235
# Epoch 282/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.6720e-04 - mae: 0.0240 - val_loss: 8.0660e-04 - val_mae: 0.0234
# Epoch 283/500
# 33/33 [==============================] - 6s 180ms/step - loss: 6.3880e-04 - mae: 0.0230 - val_loss: 8.5899e-04 - val_mae: 0.0245
# Epoch 284/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.4063e-04 - mae: 0.0230 - val_loss: 7.7829e-04 - val_mae: 0.0220
# Epoch 285/500
# 33/33 [==============================] - 6s 171ms/step - loss: 6.4529e-04 - mae: 0.0230 - val_loss: 7.9902e-04 - val_mae: 0.0232
# Epoch 286/500
# 33/33 [==============================] - 6s 170ms/step - loss: 6.3617e-04 - mae: 0.0229 - val_loss: 9.3591e-04 - val_mae: 0.0270
# Epoch 287/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.5810e-04 - mae: 0.0235 - val_loss: 7.7240e-04 - val_mae: 0.0214
# Epoch 288/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.5427e-04 - mae: 0.0235 - val_loss: 7.8201e-04 - val_mae: 0.0228
# Epoch 289/500
# 33/33 [==============================] - 6s 169ms/step - loss: 7.0055e-04 - mae: 0.0248 - val_loss: 8.3000e-04 - val_mae: 0.0253
# Epoch 290/500
# 33/33 [==============================] - 6s 187ms/step - loss: 6.7646e-04 - mae: 0.0239 - val_loss: 7.8725e-04 - val_mae: 0.0224
# Epoch 291/500
# 33/33 [==============================] - 6s 189ms/step - loss: 6.6354e-04 - mae: 0.0237 - val_loss: 8.7654e-04 - val_mae: 0.0253
# Epoch 292/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.4584e-04 - mae: 0.0230 - val_loss: 8.0384e-04 - val_mae: 0.0229
# Epoch 293/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.5934e-04 - mae: 0.0234 - val_loss: 8.0035e-04 - val_mae: 0.0230
# Epoch 294/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.3842e-04 - mae: 0.0228 - val_loss: 8.9064e-04 - val_mae: 0.0256
# Epoch 295/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.5599e-04 - mae: 0.0240 - val_loss: 8.2445e-04 - val_mae: 0.0234
# Epoch 296/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.2625e-04 - mae: 0.0225 - val_loss: 7.9558e-04 - val_mae: 0.0219
# Epoch 297/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.3018e-04 - mae: 0.0227 - val_loss: 7.8006e-04 - val_mae: 0.0214
# Epoch 298/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.5110e-04 - mae: 0.0233 - val_loss: 7.8250e-04 - val_mae: 0.0225
# Epoch 299/500
# 33/33 [==============================] - 6s 171ms/step - loss: 6.5810e-04 - mae: 0.0242 - val_loss: 7.8397e-04 - val_mae: 0.0234
# Epoch 300/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.3334e-04 - mae: 0.0228 - val_loss: 7.8988e-04 - val_mae: 0.0223
# Epoch 301/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.3230e-04 - mae: 0.0229 - val_loss: 7.8858e-04 - val_mae: 0.0220
# Epoch 302/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.4090e-04 - mae: 0.0233 - val_loss: 8.8432e-04 - val_mae: 0.0265
# Epoch 303/500
# 33/33 [==============================] - 6s 176ms/step - loss: 7.0374e-04 - mae: 0.0253 - val_loss: 7.8202e-04 - val_mae: 0.0232
# Epoch 304/500
# 33/33 [==============================] - 6s 170ms/step - loss: 6.4858e-04 - mae: 0.0235 - val_loss: 8.2138e-04 - val_mae: 0.0230
# Epoch 305/500
# 33/33 [==============================] - 6s 182ms/step - loss: 6.9319e-04 - mae: 0.0245 - val_loss: 7.9328e-04 - val_mae: 0.0218
# Epoch 306/500
# 33/33 [==============================] - 6s 184ms/step - loss: 6.2993e-04 - mae: 0.0223 - val_loss: 8.2409e-04 - val_mae: 0.0236
# Epoch 307/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.8403e-04 - mae: 0.0248 - val_loss: 8.5368e-04 - val_mae: 0.0244
# Epoch 308/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.4038e-04 - mae: 0.0227 - val_loss: 7.6850e-04 - val_mae: 0.0223
# Epoch 309/500
# 33/33 [==============================] - 6s 171ms/step - loss: 7.0364e-04 - mae: 0.0250 - val_loss: 8.7246e-04 - val_mae: 0.0266
# Epoch 310/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.9980e-04 - mae: 0.0246 - val_loss: 7.8919e-04 - val_mae: 0.0231
# Epoch 311/500
# 33/33 [==============================] - 6s 186ms/step - loss: 6.4718e-04 - mae: 0.0236 - val_loss: 8.5267e-04 - val_mae: 0.0243
# Epoch 312/500
# 33/33 [==============================] - 6s 188ms/step - loss: 6.5564e-04 - mae: 0.0236 - val_loss: 7.9205e-04 - val_mae: 0.0220
# Epoch 313/500
# 33/33 [==============================] - 6s 194ms/step - loss: 6.6324e-04 - mae: 0.0236 - val_loss: 8.1665e-04 - val_mae: 0.0230
# Epoch 314/500
# 33/33 [==============================] - 6s 189ms/step - loss: 6.8546e-04 - mae: 0.0245 - val_loss: 7.7596e-04 - val_mae: 0.0226
# Epoch 315/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.7098e-04 - mae: 0.0242 - val_loss: 7.7238e-04 - val_mae: 0.0223
# Epoch 316/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.2824e-04 - mae: 0.0226 - val_loss: 7.7102e-04 - val_mae: 0.0225
# Epoch 317/500
# 33/33 [==============================] - 6s 179ms/step - loss: 6.2805e-04 - mae: 0.0224 - val_loss: 8.2404e-04 - val_mae: 0.0236
# Epoch 318/500
# 33/33 [==============================] - 6s 193ms/step - loss: 6.5720e-04 - mae: 0.0240 - val_loss: 0.0011 - val_mae: 0.0315
# Epoch 319/500
# 33/33 [==============================] - 6s 186ms/step - loss: 6.7292e-04 - mae: 0.0243 - val_loss: 7.8514e-04 - val_mae: 0.0222
# Epoch 320/500
# 33/33 [==============================] - 7s 205ms/step - loss: 6.5994e-04 - mae: 0.0239 - val_loss: 7.6336e-04 - val_mae: 0.0218
# Epoch 321/500
# 33/33 [==============================] - 7s 216ms/step - loss: 6.3469e-04 - mae: 0.0228 - val_loss: 7.9837e-04 - val_mae: 0.0226
# Epoch 322/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.4795e-04 - mae: 0.0229 - val_loss: 8.0245e-04 - val_mae: 0.0232
# Epoch 323/500
# 33/33 [==============================] - 6s 187ms/step - loss: 6.5968e-04 - mae: 0.0239 - val_loss: 7.6658e-04 - val_mae: 0.0208
# Epoch 324/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.4151e-04 - mae: 0.0227 - val_loss: 8.0705e-04 - val_mae: 0.0230
# Epoch 325/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.3917e-04 - mae: 0.0227 - val_loss: 7.7570e-04 - val_mae: 0.0217
# Epoch 326/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.3648e-04 - mae: 0.0231 - val_loss: 8.1281e-04 - val_mae: 0.0225
# Epoch 327/500
# 33/33 [==============================] - 6s 184ms/step - loss: 6.4106e-04 - mae: 0.0231 - val_loss: 8.8613e-04 - val_mae: 0.0254
# Epoch 328/500
# 33/33 [==============================] - 6s 187ms/step - loss: 6.6500e-04 - mae: 0.0236 - val_loss: 8.1455e-04 - val_mae: 0.0227
# Epoch 329/500
# 33/33 [==============================] - 6s 183ms/step - loss: 6.3818e-04 - mae: 0.0226 - val_loss: 7.8374e-04 - val_mae: 0.0224
# Epoch 330/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.3332e-04 - mae: 0.0226 - val_loss: 7.7385e-04 - val_mae: 0.0227
# Epoch 331/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.7789e-04 - mae: 0.0239 - val_loss: 8.5694e-04 - val_mae: 0.0259
# Epoch 332/500
# 33/33 [==============================] - 6s 180ms/step - loss: 7.1291e-04 - mae: 0.0259 - val_loss: 7.6662e-04 - val_mae: 0.0223
# Epoch 333/500
# 33/33 [==============================] - 6s 175ms/step - loss: 7.0043e-04 - mae: 0.0250 - val_loss: 7.9422e-04 - val_mae: 0.0218
# Epoch 334/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.4942e-04 - mae: 0.0237 - val_loss: 7.9029e-04 - val_mae: 0.0220
# Epoch 335/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.3208e-04 - mae: 0.0224 - val_loss: 7.8362e-04 - val_mae: 0.0227
# Epoch 336/500
# 33/33 [==============================] - 6s 190ms/step - loss: 6.2902e-04 - mae: 0.0226 - val_loss: 7.7826e-04 - val_mae: 0.0217
# Epoch 337/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.3814e-04 - mae: 0.0230 - val_loss: 8.3496e-04 - val_mae: 0.0242
# Epoch 338/500
# 33/33 [==============================] - 6s 177ms/step - loss: 7.1902e-04 - mae: 0.0257 - val_loss: 7.6374e-04 - val_mae: 0.0216
# Epoch 339/500
# 33/33 [==============================] - 6s 180ms/step - loss: 6.2670e-04 - mae: 0.0226 - val_loss: 7.7379e-04 - val_mae: 0.0221
# Epoch 340/500
# 33/33 [==============================] - 6s 192ms/step - loss: 7.4989e-04 - mae: 0.0258 - val_loss: 7.9364e-04 - val_mae: 0.0226
# Epoch 341/500
# 33/33 [==============================] - 6s 178ms/step - loss: 7.2050e-04 - mae: 0.0258 - val_loss: 0.0011 - val_mae: 0.0313
# Epoch 342/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.6719e-04 - mae: 0.0245 - val_loss: 9.4432e-04 - val_mae: 0.0272
# Epoch 343/500
# 33/33 [==============================] - 6s 180ms/step - loss: 6.4303e-04 - mae: 0.0228 - val_loss: 0.0010 - val_mae: 0.0299
# Epoch 344/500
# 33/33 [==============================] - 6s 170ms/step - loss: 6.6238e-04 - mae: 0.0235 - val_loss: 8.5658e-04 - val_mae: 0.0243
# Epoch 345/500
# 33/33 [==============================] - 6s 188ms/step - loss: 6.5564e-04 - mae: 0.0238 - val_loss: 7.8953e-04 - val_mae: 0.0222
# Epoch 346/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.2595e-04 - mae: 0.0223 - val_loss: 8.0194e-04 - val_mae: 0.0223
# Epoch 347/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.3731e-04 - mae: 0.0228 - val_loss: 7.8784e-04 - val_mae: 0.0226
# Epoch 348/500
# 33/33 [==============================] - 6s 188ms/step - loss: 6.4231e-04 - mae: 0.0230 - val_loss: 9.0643e-04 - val_mae: 0.0259
# Epoch 349/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.3025e-04 - mae: 0.0225 - val_loss: 7.7872e-04 - val_mae: 0.0221
# Epoch 350/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.5888e-04 - mae: 0.0237 - val_loss: 8.5888e-04 - val_mae: 0.0245
# Epoch 351/500
# 33/33 [==============================] - 6s 177ms/step - loss: 6.3283e-04 - mae: 0.0228 - val_loss: 7.8260e-04 - val_mae: 0.0224
# Epoch 352/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.9290e-04 - mae: 0.0252 - val_loss: 7.6122e-04 - val_mae: 0.0219
# Epoch 353/500
# 33/33 [==============================] - 6s 171ms/step - loss: 6.5344e-04 - mae: 0.0232 - val_loss: 9.4080e-04 - val_mae: 0.0272
# Epoch 354/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.8546e-04 - mae: 0.0246 - val_loss: 7.8369e-04 - val_mae: 0.0224
# Epoch 355/500
# 33/33 [==============================] - 6s 175ms/step - loss: 6.5335e-04 - mae: 0.0233 - val_loss: 8.0139e-04 - val_mae: 0.0225
# Epoch 356/500
# 33/33 [==============================] - 6s 180ms/step - loss: 6.2443e-04 - mae: 0.0226 - val_loss: 8.0750e-04 - val_mae: 0.0228
# Epoch 357/500
# 33/33 [==============================] - 6s 180ms/step - loss: 6.4051e-04 - mae: 0.0232 - val_loss: 7.6468e-04 - val_mae: 0.0219
# Epoch 358/500
# 33/33 [==============================] - 6s 171ms/step - loss: 6.4827e-04 - mae: 0.0230 - val_loss: 7.9767e-04 - val_mae: 0.0232
# Epoch 359/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.4816e-04 - mae: 0.0234 - val_loss: 7.7134e-04 - val_mae: 0.0225
# Epoch 360/500
# 33/33 [==============================] - 6s 169ms/step - loss: 6.4592e-04 - mae: 0.0232 - val_loss: 8.5714e-04 - val_mae: 0.0244
# Epoch 361/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.4982e-04 - mae: 0.0234 - val_loss: 8.5815e-04 - val_mae: 0.0255
# Epoch 362/500
# 33/33 [==============================] - 6s 178ms/step - loss: 6.7777e-04 - mae: 0.0241 - val_loss: 7.8268e-04 - val_mae: 0.0232
# Epoch 363/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.3035e-04 - mae: 0.0227 - val_loss: 7.9118e-04 - val_mae: 0.0224
# Epoch 364/500
# 33/33 [==============================] - 6s 174ms/step - loss: 6.8589e-04 - mae: 0.0245 - val_loss: 8.8325e-04 - val_mae: 0.0249
# Epoch 365/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.8620e-04 - mae: 0.0246 - val_loss: 7.7285e-04 - val_mae: 0.0224
# Epoch 366/500
# 33/33 [==============================] - 6s 173ms/step - loss: 6.4655e-04 - mae: 0.0231 - val_loss: 8.9449e-04 - val_mae: 0.0257
# Epoch 367/500
# 33/33 [==============================] - 6s 180ms/step - loss: 6.6632e-04 - mae: 0.0243 - val_loss: 7.6370e-04 - val_mae: 0.0219
# Epoch 368/500
# 33/33 [==============================] - 6s 175ms/step - loss: 7.0599e-04 - mae: 0.0244 - val_loss: 8.1460e-04 - val_mae: 0.0230
# Epoch 369/500
# 33/33 [==============================] - 6s 172ms/step - loss: 6.2555e-04 - mae: 0.0226 - val_loss: 9.6030e-04 - val_mae: 0.0277
# Epoch 370/500
# 33/33 [==============================] - 6s 176ms/step - loss: 6.5487e-04 - mae: 0.0234 - val_loss: 8.4953e-04 - val_mae: 0.0238
# Epoch 371/500
# 33/33 [==============================] - 6s 193ms/step - loss: 6.5829e-04 - mae: 0.0236 - val_loss: 7.6863e-04 - val_mae: 0.0214
# Epoch 372/500
# 33/33 [==============================] - 6s 181ms/step - loss: 6.3258e-04 - mae: 0.0227 - val_loss: 7.6726e-04 - val_mae: 0.0210
# Epoch 373/500
# 33/33 [==============================] - 6s 184ms/step - loss: 6.6271e-04 - mae: 0.0237 - val_loss: 7.6686e-04 - val_mae: 0.0223

# %%
plot_history(history = history)

# %% [markdown]
# ## Get the Validation MAE for Simple RNN

# %%
get_val_mae(history=history)
# Out:
# Best epoch: 323, Best val_mae: 0.0208

# %% [markdown]
# ## Function to forecast N number of days

# %%
def forecast_next_n_days(model, series, seq_length, n_steps=1):
    """
    Forecast the next n_steps using a trained RNN model.
    
    Parameters:
    - model: trained Keras RNN model
    - series: 1D numpy array or pandas series of time series data
    - seq_length: number of timesteps used as input for the model
    - n_steps: number of steps ahead to forecast (default 1)
    
    Returns:
    - preds: list of forecasted values
    """
    
    # Get the last seq_length values
    window = series[-seq_length:].reshape(1, seq_length, 1)
    preds = []
    
    for _ in range(n_steps):
        y_pred = model.predict(window, verbose=0)[0][0]
        preds.append(y_pred)
        
        # Slide the window for the next step
        window = np.concatenate([window[:, 1:, :], y_pred.reshape(1, 1, 1)], axis=1)
    
    return preds

# %%
next_day = forecast_next_n_days(univar_model, rail_valid.to_numpy(), seq_length=56, n_steps=1) 
print("Next day forecast:", next_day[0] * 1e6)
original = df["rail"]["2025-06-01"]
print("Next day original:", original)
# Out:
# Next day forecast: 260839.67089653015
# Next day original: 268696

# %% [markdown]
# # Forecast Comparison
#
#
# |                          | Seasonal Naive Forecast | ARIMA        | Linear Model  | Simple RNN  |
# |--------------------------|------------------------|-------------|---------------|-------------|
# | **MAE**                  | 29,453.49             | 25,162.19   | 23,800        | 20,800      |
# | **Forecast (1st June 2025)** | 272,960           | 260,176.11  | 218,240.92    | 260,839.67  |
# | **Observed**             | 268,696               | 268,696     | 268,696       | 268,696     |
# | **Error %**              | 1.58%                 | 3.15%       | 18.73%       | 2.92%       |
#
# - For the **specific forecast of June 1st, 2025**, the **Seasonal Naive Forecast** is closest to the observed value.
# - For **overall long-term performance**, the **Simple RNN** achieves the lowest MAE, making it the best choice for general forecasting.
# - **Recommendation:** Use **Simple RNN** for long-term predictions and **Naive Forecast** if a single-day accuracy is the main priority.

# %% [markdown]
# # FORECASTING USING A DEEP RNN

# %%
print(text)
